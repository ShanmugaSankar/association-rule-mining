# %% [markdown]
# # Apriori Algorithim

# %%
import pandas as pd
import numpy as np
from itertools import chain,combinations
import time

# %%
def readData(path):
    '''
    Function to read csv file containing the transactions
    
    Parameters:-
    path - Location of the input file
    
    '''
    transactionData = pd.read_csv(path, header = None)
    return transactionData

# %%
def frequency(transactionData,support):
    '''Fucntion to determine the frequent items in the transaction database
    
    Parameters:-
    transactionData - Single column dataframe containing all the transactions
    support         - User determined support level for generating itemsets
    
    '''
    
    ## Extract transaction information from dataframe to a list
    Transactions = []
    for i in range(len(transactionData)):
        Transactions.append(transactionData[0][i].split(","))
    
    ## Initialize dictionaries to store frequent itemsets
    FrequentItemSets = {}
    AprioriResults = {}
    
    ## Calculate total no. of occurrences of items among all transactions
    for i,items in enumerate(Transactions):
        for j in range(len(items)):
            if items[j] in FrequentItemSets:
                FrequentItemSets[items[j]] += 1
            else:
                FrequentItemSets[items[j]] = 1

    association = []
    nonFrequent = []
    
    ## Assign items to the lists depending on whether they meet the minimum support
    for i in FrequentItemSets:
        if FrequentItemSets[i]/len(Transactions) >= support:
            association.append(i)
        else:
            nonFrequent.append(i)
    
    ## Delete all items which do not meet the minimum support requirement
    for i in nonFrequent:
        del FrequentItemSets[i]

    n_combinations = list(combinations(association,2))
    return n_combinations,Transactions,FrequentItemSets,AprioriResults

# %%
def support_level(n_combinations,support,Transactions,AprioriResults):
    '''
    Function to determine all itemset combinations which meet the minimum support
    
    Parameters:-
    n_combinations - List of all itemset combinations meeting the support requirement
    support        - User determined support level for generating itemsets
    Transaction    - List containing all transactions
    AprioriResults - Dictionary containing all itemsets meeting support level
    
    '''
    
    ## Loop to generate itemsets as long as they meet support requirements
    while len(n_combinations) > 0:
        itemSets = []
        for i in n_combinations:
            count = 0
            for j in range(len(Transactions)):
                if set(i).issubset(Transactions[j]) == True: ## for itemsets present in transactions, increase count
                     count += 1
            if count/len(Transactions) >= support:           ## if itemset meets minimum support add it to dictionary
                itemSets.append(i)
                AprioriResults[tuple(sorted(i))] = count
         
        addition = []
        
        ## Loop to generate (n+1)th itemset
        for i in range(len(itemSets)):
            j = len(itemSets) - 1
            while j > i:                                     ## Generating (n+1)th itemset, eg. (A,B),(A,C) => (A,B,C)
                if len(list(set(itemSets[i]) - set(itemSets[j]))) == 1 and set(itemSets[i]).intersection(set(itemSets[j])) != set():
                    addition.append(tuple(sorted(set(itemSets[i]).intersection(set(itemSets[j])).union(set(itemSets[i]).symmetric_difference(set(itemSets[j]))))))
                j -= 1
        ## List of new itemsets for which support levels need to be checked        
        n_combinations = list(frozenset(sorted(sub)) for sub in set(sorted(addition)))
        
    return AprioriResults

# %%
def confidence_level(AprioriResults,FrequentItemSets,Transactions,confidence,support):
    '''
    Function to generate the support and confidence levels of itemsets which meet user defined requirements
    
    Parameters:-
    ApriroiResults   -  Dictionary containing frequent itemsets
    FrequentItemSets -  Dictionary containing frequent items
    Transactions     -  List containing all transactions
    confidence       -  User determined confidence level for generating itemsets
    support          -  User determined support level for generating itemsets
    
    '''
    ## iterate over itemsets which are greater than minimum support level
    for i,combination in enumerate(AprioriResults):  
    ## iterate to get association of 1 item to the rest of the set
        for j in combination:
            ## for 2-itemsets
            if len(set(combination) - set((j,))) == 1:
                BaseGroup = list(set(combination) - set((j,)),)[0]
                ## calculate support and confidence level
                confidenceCalculation  = AprioriResults.get(combination)/FrequentItemSets.get(BaseGroup)
                supportLevel = AprioriResults.get(combination)/len(Transactions)
                ## print valid associations
                if confidenceCalculation >= confidence and supportLevel >= support:
                    print(set((BaseGroup,)),"=>","{",j,"}","(",supportLevel*100,"%,",confidenceCalculation*100,"%",")")
            ## for n-itemsets, where n > 2
            else:
                BaseGroup = tuple(set(combination) - set((j,)))
                ## calculate support and confidence level
                confidenceCalculation  = AprioriResults.get(combination)/AprioriResults.get(tuple(sorted(BaseGroup)))
                supportLevel = AprioriResults.get(combination)/len(Transactions)
                ## print valid associations
                if confidenceCalculation >= confidence and supportLevel >= support:
                    print(set(BaseGroup),"=>","{",j,"}","(",supportLevel*100,"%,",confidenceCalculation*100,"%",")")
                
            FrequentItemSets[combination] = AprioriResults.get(combination)

# %%
def Apriori(support,confidence,path):
    '''
    Function to execute Apriori Algorithim
    
    Parameters:-
    support     -  User determined support level for generating itemsets
    confidence  -  User determined confidence level for generating itemsets
    path        -  Location of the input file
    
    '''
    
    transactionData = readData(path)
    n_combinations,Transactions,FrequentItemSets,AprioriResults = frequency(transactionData,support)
    AprioriResults = support_level(n_combinations,support,Transactions,AprioriResults)
    return confidence_level(AprioriResults,FrequentItemSets,Transactions,confidence,support)

# %% [markdown]
# ## Apriori Algorithm Execution on Datasets

# %%
## Executing Apriori Algorithm on Dataset 1
start_time = time.time()
Apriori(.15,.55,"C:/Users/Shank/Desktop/NJIT/CourseMaterial/Spring2022/DataMining/MidTermProject/WorkingDirectory/TransactionDatabase/Database1.csv")
print("Time to execute Apriori Algorithim --- %s seconds" % (time.time() - start_time))
# Out:
# {'Milk'} => { Eggs } ( 15.0 %, 75.0 % )
# {'Eggs'} => { Milk } ( 15.0 %, 100.0 % )
# {'ShavingCream'} => { RazerBlades } ( 15.0 %, 75.0 % )
# {'RazerBlades'} => { ShavingCream } ( 15.0 %, 100.0 % )
# {'ShavingCream'} => { Moisturizer } ( 15.0 %, 75.0 % )
# {'Moisturizer'} => { ShavingCream } ( 15.0 %, 75.0 % )
# Time to execute Apriori Algorithim --- 0.008975982666015625 seconds

# %%
## Executing Apriori Algorithm on Dataset 2
start_time = time.time()
Apriori(.35,.85,"C:/Users/Shank/Desktop/NJIT/CourseMaterial/Spring2022/DataMining/MidTermProject/WorkingDirectory/TransactionDatabase/Database2.csv")
print("Time to execute Apriori Algorithim --- %s seconds" % (time.time() - start_time))
# Out:
# {'Banana'} => { Tomato } ( 35.0 %, 87.5 % )
# {'WetWipes'} => { Moisturizer } ( 35.0 %, 87.5 % )
# {'Onion'} => { RazerBlades } ( 35.0 %, 87.5 % )
# {'WetWipes'} => { Notebook } ( 35.0 %, 87.5 % )
# {'Sunscreen', 'WaterBottle'} => { MangoJuice } ( 35.0 %, 87.5 % )
# {'Sunscreen', 'MangoJuice'} => { WaterBottle } ( 35.0 %, 100.0 % )
# {'Notebook', 'Tomato'} => { RazerBlades } ( 35.0 %, 87.5 % )
# {'WaterBottle', 'Eggs'} => { Moisturizer } ( 35.0 %, 87.5 % )
# {'Moisturizer', 'Eggs'} => { WaterBottle } ( 35.0 %, 87.5 % )
# {'Moisturizer', 'Notebook'} => { Eggs } ( 35.0 %, 87.5 % )
# {'Notebook', 'Eggs'} => { Moisturizer } ( 35.0 %, 87.5 % )
# {'Moisturizer', 'Eggs'} => { Notebook } ( 35.0 %, 87.5 % )
# {'WaterBottle', 'Eggs'} => { Notebook } ( 35.0 %, 87.5 % )
# {'Notebook', 'Eggs'} => { WaterBottle } ( 35.0 %, 87.5 % )
# {'Bed', 'RazerBlades'} => { Notebook } ( 35.0 %, 87.5 % )
# {'Moisturizer', 'MangoJuice'} => { WaterBottle } ( 35.0 %, 87.5 % )
# {'MangoJuice', 'RazerBlades'} => { Tomato } ( 35.0 %, 87.5 % )
# {'Shoes', 'RazerBlades'} => { Notebook } ( 35.0 %, 100.0 % )
# {'Notebook', 'Shoes'} => { RazerBlades } ( 35.0 %, 87.5 % )
# {'Desk', 'RazerBlades'} => { Moisturizer } ( 35.0 %, 100.0 % )
# {'HardDisk', 'Fan'} => { Tomato } ( 35.0 %, 87.5 % )
# {'Tomato', 'Shoes'} => { Fan } ( 35.0 %, 87.5 % )
# {'Fan', 'Shoes'} => { Tomato } ( 35.0 %, 87.5 % )
# {'Umbrella', 'Mouse'} => { Eggs } ( 35.0 %, 87.5 % )
# {'Umbrella', 'Eggs'} => { Mouse } ( 35.0 %, 100.0 % )
# {'Mouse', 'Eggs'} => { Umbrella } ( 35.0 %, 87.5 % )
# {'RazerBlades', 'Eggs'} => { Moisturizer } ( 35.0 %, 100.0 % )
# {'Moisturizer', 'Eggs'} => { RazerBlades } ( 35.0 %, 87.5 % )
# {'Moisturizer', 'Notebook'} => { RazerBlades } ( 35.0 %, 87.5 % )
# {'Bed', 'WaterBottle'} => { Notebook } ( 35.0 %, 87.5 % )
# {'WaterBottle', 'RazerBlades'} => { Moisturizer } ( 35.0 %, 87.5 % )
# {'Desk', 'WaterBottle'} => { Moisturizer } ( 35.0 %, 87.5 % )
# {'Moisturizer', 'MangoJuice'} => { Tomato } ( 35.0 %, 87.5 % )
# Time to execute Apriori Algorithim --- 0.05389285087585449 seconds

# %%
## Executing Apriori Algorithm on Dataset 3
start_time = time.time()
Apriori(.35,.55,"C:/Users/Shank/Desktop/NJIT/CourseMaterial/Spring2022/DataMining/MidTermProject/WorkingDirectory/TransactionDatabase/Database3.csv")
print("Time to execute Apriori Algorithim --- %s seconds" % (time.time() - start_time))
# Out:
# {'Milk'} => { MangoJuice } ( 55.00000000000001 %, 68.75 % )
# {'MangoJuice'} => { Milk } ( 55.00000000000001 %, 91.66666666666666 % )
# {'Lamp'} => { Milk } ( 40.0 %, 88.88888888888889 % )
# {'Bed'} => { Milk } ( 35.0 %, 70.0 % )
# {'Fan'} => { Milk } ( 35.0 %, 87.5 % )
# {'Milk'} => { Banana } ( 50.0 %, 62.5 % )
# {'Banana'} => { Milk } ( 50.0 %, 76.92307692307693 % )
# {'Moisturizer'} => { Milk } ( 35.0 %, 77.77777777777779 % )
# {'Sunscreen'} => { Milk } ( 35.0 %, 77.77777777777779 % )
# {'Eggs'} => { Milk } ( 35.0 %, 77.77777777777779 % )
# {'ChickenBreast'} => { Milk } ( 40.0 %, 88.88888888888889 % )
# {'Milk'} => { Chocolates } ( 50.0 %, 62.5 % )
# {'Chocolates'} => { Milk } ( 50.0 %, 100.0 % )
# {'Notebook'} => { Milk } ( 45.0 %, 100.0 % )
# {'Milk'} => { Notebook } ( 45.0 %, 56.25 % )
# {'Pen'} => { Milk } ( 40.0 %, 80.0 % )
# {'Shoes'} => { Milk } ( 45.0 %, 81.81818181818183 % )
# {'Milk'} => { Shoes } ( 45.0 %, 56.25 % )
# {'Mouse'} => { Milk } ( 50.0 %, 76.92307692307693 % )
# {'Milk'} => { Mouse } ( 50.0 %, 62.5 % )
# {'WetWipes'} => { Milk } ( 50.0 %, 90.9090909090909 % )
# {'Milk'} => { WetWipes } ( 50.0 %, 62.5 % )
# {'Tomato'} => { Milk } ( 45.0 %, 90.0 % )
# {'Milk'} => { Tomato } ( 45.0 %, 56.25 % )
# {'WaterBottle'} => { Milk } ( 50.0 %, 76.92307692307693 % )
# {'Milk'} => { WaterBottle } ( 50.0 %, 62.5 % )
# {'LightBulb'} => { Milk } ( 40.0 %, 80.0 % )
# {'Umbrella'} => { Milk } ( 40.0 %, 72.72727272727273 % )
# {'Chips'} => { Banana } ( 35.0 %, 87.5 % )
# {'MangoJuice'} => { Banana } ( 45.0 %, 75.0 % )
# {'Banana'} => { MangoJuice } ( 45.0 %, 69.23076923076923 % )
# {'MangoJuice'} => { Eggs } ( 35.0 %, 58.333333333333336 % )
# {'Eggs'} => { MangoJuice } ( 35.0 %, 77.77777777777779 % )
# {'MangoJuice'} => { Chocolates } ( 35.0 %, 58.333333333333336 % )
# {'Chocolates'} => { MangoJuice } ( 35.0 %, 70.0 % )
# {'Pen'} => { MangoJuice } ( 40.0 %, 80.0 % )
# {'MangoJuice'} => { Pen } ( 40.0 %, 66.66666666666666 % )
# {'Mouse'} => { MangoJuice } ( 45.0 %, 69.23076923076923 % )
# {'MangoJuice'} => { Mouse } ( 45.0 %, 75.0 % )
# {'WaterBottle'} => { MangoJuice } ( 40.0 %, 61.53846153846154 % )
# {'MangoJuice'} => { WaterBottle } ( 40.0 %, 66.66666666666666 % )
# {'Moisturizer'} => { Bed } ( 35.0 %, 77.77777777777779 % )
# {'Bed'} => { Moisturizer } ( 35.0 %, 70.0 % )
# {'Shoes'} => { Bed } ( 35.0 %, 63.63636363636363 % )
# {'Bed'} => { Shoes } ( 35.0 %, 70.0 % )
# {'Eggs'} => { Banana } ( 35.0 %, 77.77777777777779 % )
# {'Notebook'} => { Banana } ( 35.0 %, 77.77777777777779 % )
# {'Pen'} => { Banana } ( 40.0 %, 80.0 % )
# {'Banana'} => { Pen } ( 40.0 %, 61.53846153846154 % )
# {'Shoes'} => { Banana } ( 40.0 %, 72.72727272727273 % )
# {'Banana'} => { Shoes } ( 40.0 %, 61.53846153846154 % )
# {'Mouse'} => { Banana } ( 50.0 %, 76.92307692307693 % )
# {'Banana'} => { Mouse } ( 50.0 %, 76.92307692307693 % )
# {'RazerBlades'} => { Banana } ( 35.0 %, 87.5 % )
# {'WetWipes'} => { Banana } ( 35.0 %, 63.63636363636363 % )
# {'WaterBottle'} => { Banana } ( 40.0 %, 61.53846153846154 % )
# {'Banana'} => { WaterBottle } ( 40.0 %, 61.53846153846154 % )
# {'Umbrella'} => { Banana } ( 35.0 %, 63.63636363636363 % )
# {'Sunscreen'} => { WaterBottle } ( 35.0 %, 77.77777777777779 % )
# {''} => { WaterBottle } ( 35.0 %, 77.77777777777779 % )
# {'Pen'} => { Eggs } ( 40.0 %, 80.0 % )
# {'Eggs'} => { Pen } ( 40.0 %, 88.88888888888889 % )
# {'Shoes'} => { Eggs } ( 35.0 %, 63.63636363636363 % )
# {'Eggs'} => { Shoes } ( 35.0 %, 77.77777777777779 % )
# {'ChickenBreast'} => { Mouse } ( 35.0 %, 77.77777777777779 % )
# {'Mouse'} => { Chocolates } ( 40.0 %, 61.53846153846154 % )
# {'Chocolates'} => { Mouse } ( 40.0 %, 80.0 % )
# {'WetWipes'} => { Chocolates } ( 40.0 %, 72.72727272727273 % )
# {'Chocolates'} => { WetWipes } ( 40.0 %, 80.0 % )
# {'Chocolates'} => { WaterBottle } ( 35.0 %, 70.0 % )
# {'Shoes'} => { Notebook } ( 35.0 %, 63.63636363636363 % )
# {'Notebook'} => { Shoes } ( 35.0 %, 77.77777777777779 % )
# {'Notebook'} => { Mouse } ( 35.0 %, 77.77777777777779 % )
# {'WetWipes'} => { Notebook } ( 40.0 %, 72.72727272727273 % )
# {'Notebook'} => { WetWipes } ( 40.0 %, 88.88888888888889 % )
# {'Pen'} => { Mouse } ( 40.0 %, 80.0 % )
# {'Mouse'} => { Pen } ( 40.0 %, 61.53846153846154 % )
# {'Tomato'} => { Pen } ( 35.0 %, 70.0 % )
# {'Pen'} => { Tomato } ( 35.0 %, 70.0 % )
# {'Pen'} => { WaterBottle } ( 35.0 %, 70.0 % )
# {'Shoes'} => { Mouse } ( 35.0 %, 63.63636363636363 % )
# {'WetWipes'} => { Shoes } ( 35.0 %, 63.63636363636363 % )
# {'Shoes'} => { WetWipes } ( 35.0 %, 63.63636363636363 % )
# {'Tomato'} => { Shoes } ( 35.0 %, 70.0 % )
# {'Shoes'} => { Tomato } ( 35.0 %, 63.63636363636363 % )
# {'Shoes'} => { LightBulb } ( 35.0 %, 63.63636363636363 % )
# {'LightBulb'} => { Shoes } ( 35.0 %, 70.0 % )
# {'Umbrella'} => { Shoes } ( 35.0 %, 63.63636363636363 % )
# {'Shoes'} => { Umbrella } ( 35.0 %, 63.63636363636363 % )
# {'Shoes'} => { HardDisk } ( 35.0 %, 63.63636363636363 % )
# {'HardDisk'} => { Shoes } ( 35.0 %, 87.5 % )
# {'WetWipes'} => { Mouse } ( 40.0 %, 72.72727272727273 % )
# {'Mouse'} => { WetWipes } ( 40.0 %, 61.53846153846154 % )
# {'WaterBottle'} => { Mouse } ( 45.0 %, 69.23076923076923 % )
# {'Mouse'} => { WaterBottle } ( 45.0 %, 69.23076923076923 % )
# {'Mouse'} => { LightBulb } ( 40.0 %, 61.53846153846154 % )
# {'LightBulb'} => { Mouse } ( 40.0 %, 80.0 % )
# {'Umbrella'} => { Mouse } ( 35.0 %, 63.63636363636363 % )
# {'WetWipes'} => { Tomato } ( 35.0 %, 63.63636363636363 % )
# {'Tomato'} => { WetWipes } ( 35.0 %, 70.0 % )
# {'WetWipes'} => { HardDisk } ( 35.0 %, 63.63636363636363 % )
# {'HardDisk'} => { WetWipes } ( 35.0 %, 87.5 % )
# {'Tomato'} => { WaterBottle } ( 35.0 %, 70.0 % )
# {'LightBulb'} => { WaterBottle } ( 35.0 %, 70.0 % )
# {'Umbrella'} => { WaterBottle } ( 35.0 %, 63.63636363636363 % )
# {'Shorts'} => { WaterBottle } ( 35.0 %, 100.0 % )
# {'Milk', 'MangoJuice'} => { Chocolates } ( 35.0 %, 63.63636363636363 % )
# {'Chocolates', 'Milk'} => { MangoJuice } ( 35.0 %, 70.0 % )
# {'Chocolates', 'MangoJuice'} => { Milk } ( 35.0 %, 100.0 % )
# {'Pen', 'Milk'} => { Eggs } ( 35.0 %, 87.5 % )
# {'Pen', 'Eggs'} => { Milk } ( 35.0 %, 87.5 % )
# {'Milk', 'Eggs'} => { Pen } ( 35.0 %, 100.0 % )
# {'Pen', 'MangoJuice'} => { Eggs } ( 35.0 %, 87.5 % )
# {'Pen', 'Eggs'} => { MangoJuice } ( 35.0 %, 87.5 % )
# {'MangoJuice', 'Eggs'} => { Pen } ( 35.0 %, 100.0 % )
# {'Milk', 'Mouse'} => { Chocolates } ( 40.0 %, 80.0 % )
# {'Chocolates', 'Mouse'} => { Milk } ( 40.0 %, 100.0 % )
# {'Chocolates', 'Milk'} => { Mouse } ( 40.0 %, 80.0 % )
# {'Milk', 'WaterBottle'} => { MangoJuice } ( 35.0 %, 70.0 % )
# {'WaterBottle', 'MangoJuice'} => { Milk } ( 35.0 %, 87.5 % )
# {'Milk', 'MangoJuice'} => { WaterBottle } ( 35.0 %, 63.63636363636363 % )
# {'Pen', 'Milk'} => { MangoJuice } ( 35.0 %, 87.5 % )
# {'Pen', 'MangoJuice'} => { Milk } ( 35.0 %, 87.5 % )
# {'Milk', 'MangoJuice'} => { Pen } ( 35.0 %, 63.63636363636363 % )
# {'Tomato', 'Shoes'} => { Milk } ( 35.0 %, 100.0 % )
# {'Milk', 'Tomato'} => { Shoes } ( 35.0 %, 77.77777777777779 % )
# {'Milk', 'Shoes'} => { Tomato } ( 35.0 %, 77.77777777777779 % )
# {'Notebook', 'Mouse'} => { Milk } ( 35.0 %, 100.0 % )
# {'Notebook', 'Milk'} => { Mouse } ( 35.0 %, 77.77777777777779 % )
# {'Milk', 'Mouse'} => { Notebook } ( 35.0 %, 70.0 % )
# {'Milk', 'WetWipes'} => { Chocolates } ( 40.0 %, 80.0 % )
# {'Chocolates', 'WetWipes'} => { Milk } ( 40.0 %, 100.0 % )
# {'Chocolates', 'Milk'} => { WetWipes } ( 40.0 %, 80.0 % )
# {'Notebook', 'Shoes'} => { Milk } ( 35.0 %, 100.0 % )
# {'Milk', 'Shoes'} => { Notebook } ( 35.0 %, 77.77777777777779 % )
# {'Notebook', 'Milk'} => { Shoes } ( 35.0 %, 77.77777777777779 % )
# {'Milk', 'MangoJuice'} => { Banana } ( 40.0 %, 72.72727272727273 % )
# {'Banana', 'Milk'} => { MangoJuice } ( 40.0 %, 80.0 % )
# {'Banana', 'MangoJuice'} => { Milk } ( 40.0 %, 88.88888888888889 % )
# {'Pen', 'Eggs'} => { Banana } ( 35.0 %, 87.5 % )
# {'Pen', 'Banana'} => { Eggs } ( 35.0 %, 87.5 % )
# {'Banana', 'Eggs'} => { Pen } ( 35.0 %, 100.0 % )
# {'Milk', 'Shoes'} => { Banana } ( 35.0 %, 77.77777777777779 % )
# {'Banana', 'Shoes'} => { Milk } ( 35.0 %, 87.5 % )
# {'Banana', 'Milk'} => { Shoes } ( 35.0 %, 70.0 % )
# {'Pen', 'Mouse'} => { MangoJuice } ( 35.0 %, 87.5 % )
# {'Pen', 'MangoJuice'} => { Mouse } ( 35.0 %, 87.5 % )
# {'Mouse', 'MangoJuice'} => { Pen } ( 35.0 %, 77.77777777777779 % )
# {'Notebook', 'Milk'} => { Banana } ( 35.0 %, 77.77777777777779 % )
# {'Notebook', 'Banana'} => { Milk } ( 35.0 %, 100.0 % )
# {'Banana', 'Milk'} => { Notebook } ( 35.0 %, 70.0 % )
# {'Mouse', 'WetWipes'} => { Milk } ( 35.0 %, 87.5 % )
# {'Milk', 'WetWipes'} => { Mouse } ( 35.0 %, 70.0 % )
# {'Milk', 'Mouse'} => { WetWipes } ( 35.0 %, 70.0 % )
# {'Tomato', 'WetWipes'} => { Milk } ( 35.0 %, 100.0 % )
# {'Milk', 'WetWipes'} => { Tomato } ( 35.0 %, 70.0 % )
# {'Milk', 'Tomato'} => { WetWipes } ( 35.0 %, 77.77777777777779 % )
# {'Mouse', 'MangoJuice'} => { Banana } ( 35.0 %, 77.77777777777779 % )
# {'Banana', 'Mouse'} => { MangoJuice } ( 35.0 %, 70.0 % )
# {'Banana', 'MangoJuice'} => { Mouse } ( 35.0 %, 77.77777777777779 % )
# {'Milk', 'Mouse'} => { MangoJuice } ( 40.0 %, 80.0 % )
# {'Mouse', 'MangoJuice'} => { Milk } ( 40.0 %, 88.88888888888889 % )
# {'Milk', 'MangoJuice'} => { Mouse } ( 40.0 %, 72.72727272727273 % )
# {'Milk', 'WaterBottle'} => { Chocolates } ( 35.0 %, 70.0 % )
# {'Chocolates', 'WaterBottle'} => { Milk } ( 35.0 %, 100.0 % )
# {'Chocolates', 'Milk'} => { WaterBottle } ( 35.0 %, 70.0 % )
# {'Milk', 'Mouse'} => { Banana } ( 35.0 %, 70.0 % )
# {'Banana', 'Mouse'} => { Milk } ( 35.0 %, 70.0 % )
# {'Banana', 'Milk'} => { Mouse } ( 35.0 %, 70.0 % )
# {'Notebook', 'WetWipes'} => { Milk } ( 40.0 %, 100.0 % )
# {'Milk', 'WetWipes'} => { Notebook } ( 40.0 %, 80.0 % )
# {'Notebook', 'Milk'} => { WetWipes } ( 40.0 %, 88.88888888888889 % )
# Time to execute Apriori Algorithim --- 0.12366938591003418 seconds

# %%
## Executing Apriori Algorithm on Dataset 4
start_time = time.time()
Apriori(.40,.55,"C:/Users/Shank/Desktop/NJIT/CourseMaterial/Spring2022/DataMining/MidTermProject/WorkingDirectory/TransactionDatabase/Database4.csv")
print("Time to execute Apriori Algorithim --- %s seconds" % (time.time() - start_time))
# Out:
# {'WaterBottle'} => { Eggs } ( 45.0 %, 64.28571428571429 % )
# {'Eggs'} => { WaterBottle } ( 45.0 %, 75.0 % )
# {'Eggs'} => { Bed } ( 40.0 %, 66.66666666666666 % )
# {'Bed'} => { Eggs } ( 40.0 %, 61.53846153846154 % )
# {'Notebook'} => { Eggs } ( 40.0 %, 72.72727272727273 % )
# {'Eggs'} => { Notebook } ( 40.0 %, 66.66666666666666 % )
# {'Shoes'} => { Eggs } ( 45.0 %, 60.0 % )
# {'Eggs'} => { Shoes } ( 45.0 %, 75.0 % )
# {'Eggs'} => { Chocolates } ( 40.0 %, 66.66666666666666 % )
# {'Chocolates'} => { Eggs } ( 40.0 %, 61.53846153846154 % )
# {'Shorts'} => { Eggs } ( 45.0 %, 69.23076923076923 % )
# {'Eggs'} => { Shorts } ( 45.0 %, 75.0 % )
# {'WaterBottle'} => { Onion } ( 40.0 %, 57.14285714285714 % )
# {'Onion'} => { WaterBottle } ( 40.0 %, 66.66666666666666 % )
# {'Onion'} => { Chips } ( 50.0 %, 83.33333333333334 % )
# {'Chips'} => { Onion } ( 50.0 %, 83.33333333333334 % )
# {'Onion'} => { Banana } ( 40.0 %, 66.66666666666666 % )
# {'Banana'} => { Onion } ( 40.0 %, 88.88888888888889 % )
# {'Shoes'} => { Onion } ( 50.0 %, 66.66666666666666 % )
# {'Onion'} => { Shoes } ( 50.0 %, 83.33333333333334 % )
# {'Umbrella'} => { Onion } ( 40.0 %, 80.0 % )
# {'Onion'} => { Umbrella } ( 40.0 %, 66.66666666666666 % )
# {'Shorts'} => { Onion } ( 40.0 %, 61.53846153846154 % )
# {'Onion'} => { Shorts } ( 40.0 %, 66.66666666666666 % )
# {'WaterBottle'} => { Milk } ( 45.0 %, 64.28571428571429 % )
# {'Milk'} => { WaterBottle } ( 45.0 %, 81.81818181818183 % )
# {'Milk'} => { Bed } ( 40.0 %, 72.72727272727273 % )
# {'Bed'} => { Milk } ( 40.0 %, 61.53846153846154 % )
# {'Water'} => { Milk } ( 45.0 %, 81.81818181818183 % )
# {'Milk'} => { Water } ( 45.0 %, 81.81818181818183 % )
# {'Shoes'} => { Milk } ( 45.0 %, 60.0 % )
# {'Milk'} => { Shoes } ( 45.0 %, 81.81818181818183 % )
# {'WaterBottle'} => { Bed } ( 50.0 %, 71.42857142857143 % )
# {'Bed'} => { WaterBottle } ( 50.0 %, 76.92307692307693 % )
# {'WaterBottle'} => { Water } ( 45.0 %, 64.28571428571429 % )
# {'Water'} => { WaterBottle } ( 45.0 %, 81.81818181818183 % )
# {'WaterBottle'} => { Shoes } ( 60.0 %, 85.71428571428571 % )
# {'Shoes'} => { WaterBottle } ( 60.0 %, 80.0 % )
# {'WaterBottle'} => { Chocolates } ( 50.0 %, 71.42857142857143 % )
# {'Chocolates'} => { WaterBottle } ( 50.0 %, 76.92307692307693 % )
# {'WaterBottle'} => { MangoJuice } ( 40.0 %, 57.14285714285714 % )
# {'MangoJuice'} => { WaterBottle } ( 40.0 %, 80.0 % )
# {'WaterBottle'} => { Lamp } ( 45.0 %, 64.28571428571429 % )
# {'Lamp'} => { WaterBottle } ( 45.0 %, 81.81818181818183 % )
# {'WaterBottle'} => { Shorts } ( 45.0 %, 64.28571428571429 % )
# {'Shorts'} => { WaterBottle } ( 45.0 %, 69.23076923076923 % )
# {'WetWipes'} => { WaterBottle } ( 40.0 %, 80.0 % )
# {'WaterBottle'} => { WetWipes } ( 40.0 %, 57.14285714285714 % )
# {'Shoes'} => { Chips } ( 50.0 %, 66.66666666666666 % )
# {'Chips'} => { Shoes } ( 50.0 %, 83.33333333333334 % )
# {'Shorts'} => { Chips } ( 40.0 %, 61.53846153846154 % )
# {'Chips'} => { Shorts } ( 40.0 %, 66.66666666666666 % )
# {'Mouse'} => { Chips } ( 40.0 %, 66.66666666666666 % )
# {'Chips'} => { Mouse } ( 40.0 %, 66.66666666666666 % )
# {'Water'} => { Bed } ( 40.0 %, 72.72727272727273 % )
# {'Bed'} => { Water } ( 40.0 %, 61.53846153846154 % )
# {'Shoes'} => { Bed } ( 55.00000000000001 %, 73.33333333333333 % )
# {'Bed'} => { Shoes } ( 55.00000000000001 %, 84.61538461538461 % )
# {'Chocolates'} => { Bed } ( 40.0 %, 61.53846153846154 % )
# {'Bed'} => { Chocolates } ( 40.0 %, 61.53846153846154 % )
# {'Shorts'} => { Bed } ( 40.0 %, 61.53846153846154 % )
# {'Bed'} => { Shorts } ( 40.0 %, 61.53846153846154 % )
# {'WetWipes'} => { Bed } ( 40.0 %, 80.0 % )
# {'Bed'} => { WetWipes } ( 40.0 %, 61.53846153846154 % )
# {'Notebook'} => {  } ( 40.0 %, 72.72727272727273 % )
# {''} => { Notebook } ( 40.0 %, 80.0 % )
# {'Water'} => { Shoes } ( 50.0 %, 90.9090909090909 % )
# {'Shoes'} => { Water } ( 50.0 %, 66.66666666666666 % )
# {'Water'} => { ShavingCream } ( 40.0 %, 72.72727272727273 % )
# {'ShavingCream'} => { Water } ( 40.0 %, 80.0 % )
# {'Banana'} => { Shoes } ( 40.0 %, 88.88888888888889 % )
# {'Moisturizer'} => { Shoes } ( 40.0 %, 80.0 % )
# {'Shoes'} => { Chocolates } ( 50.0 %, 66.66666666666666 % )
# {'Chocolates'} => { Shoes } ( 50.0 %, 76.92307692307693 % )
# {'Shoes'} => { MangoJuice } ( 45.0 %, 60.0 % )
# {'MangoJuice'} => { Shoes } ( 45.0 %, 90.0 % )
# {'Shoes'} => { Lamp } ( 45.0 %, 60.0 % )
# {'Lamp'} => { Shoes } ( 45.0 %, 81.81818181818183 % )
# {'Shorts'} => { Shoes } ( 50.0 %, 76.92307692307693 % )
# {'Shoes'} => { Shorts } ( 50.0 %, 66.66666666666666 % )
# {'Mouse'} => { Shoes } ( 40.0 %, 66.66666666666666 % )
# {'WetWipes'} => { Shoes } ( 40.0 %, 80.0 % )
# {'ChickenBreast'} => { Shoes } ( 40.0 %, 80.0 % )
# {'ShavingCream'} => { Mouse } ( 40.0 %, 80.0 % )
# {'Mouse'} => { ShavingCream } ( 40.0 %, 66.66666666666666 % )
# {'Mouse'} => {  } ( 40.0 %, 66.66666666666666 % )
# {''} => { Mouse } ( 40.0 %, 80.0 % )
# {'Lamp'} => { Chocolates } ( 45.0 %, 81.81818181818183 % )
# {'Chocolates'} => { Lamp } ( 45.0 %, 69.23076923076923 % )
# {'Shorts'} => { Chocolates } ( 45.0 %, 69.23076923076923 % )
# {'Chocolates'} => { Shorts } ( 45.0 %, 69.23076923076923 % )
# {'Mouse'} => { Chocolates } ( 50.0 %, 83.33333333333334 % )
# {'Chocolates'} => { Mouse } ( 50.0 %, 76.92307692307693 % )
# {'Shorts'} => { MangoJuice } ( 40.0 %, 61.53846153846154 % )
# {'MangoJuice'} => { Shorts } ( 40.0 %, 80.0 % )
# {'Shorts'} => { Lamp } ( 40.0 %, 61.53846153846154 % )
# {'Lamp'} => { Shorts } ( 40.0 %, 72.72727272727273 % )
# {'Shorts'} => { Mouse } ( 45.0 %, 69.23076923076923 % )
# {'Mouse'} => { Shorts } ( 45.0 %, 75.0 % )
# {'Onion', 'Shoes'} => { Chips } ( 40.0 %, 80.0 % )
# {'Shoes', 'Chips'} => { Onion } ( 40.0 %, 80.0 % )
# {'Onion', 'Chips'} => { Shoes } ( 40.0 %, 80.0 % )
# {'Water', 'WaterBottle'} => { Shoes } ( 40.0 %, 88.88888888888889 % )
# {'WaterBottle', 'Shoes'} => { Water } ( 40.0 %, 66.66666666666666 % )
# {'Water', 'Shoes'} => { WaterBottle } ( 40.0 %, 80.0 % )
# {'Water', 'Shoes'} => { Milk } ( 40.0 %, 80.0 % )
# {'Milk', 'Water'} => { Shoes } ( 40.0 %, 88.88888888888889 % )
# {'Milk', 'Shoes'} => { Water } ( 40.0 %, 88.88888888888889 % )
# {'Water', 'Shoes'} => { Bed } ( 40.0 %, 80.0 % )
# {'Bed', 'Water'} => { Shoes } ( 40.0 %, 100.0 % )
# {'Bed', 'Shoes'} => { Water } ( 40.0 %, 72.72727272727273 % )
# {'Shorts', 'Shoes'} => { Chocolates } ( 40.0 %, 80.0 % )
# {'Chocolates', 'Shorts'} => { Shoes } ( 40.0 %, 88.88888888888889 % )
# {'Chocolates', 'Shoes'} => { Shorts } ( 40.0 %, 80.0 % )
# {'Lamp', 'WaterBottle'} => { Chocolates } ( 40.0 %, 88.88888888888889 % )
# {'Chocolates', 'WaterBottle'} => { Lamp } ( 40.0 %, 80.0 % )
# {'Chocolates', 'Lamp'} => { WaterBottle } ( 40.0 %, 88.88888888888889 % )
# {'WaterBottle', 'Shoes'} => { Eggs } ( 40.0 %, 66.66666666666666 % )
# {'WaterBottle', 'Eggs'} => { Shoes } ( 40.0 %, 88.88888888888889 % )
# {'Shoes', 'Eggs'} => { WaterBottle } ( 40.0 %, 88.88888888888889 % )
# {'WaterBottle', 'Shoes'} => { Bed } ( 45.0 %, 75.0 % )
# {'Bed', 'WaterBottle'} => { Shoes } ( 45.0 %, 90.0 % )
# {'Bed', 'Shoes'} => { WaterBottle } ( 45.0 %, 81.81818181818183 % )
# {'WaterBottle', 'Shoes'} => { MangoJuice } ( 40.0 %, 66.66666666666666 % )
# {'WaterBottle', 'MangoJuice'} => { Shoes } ( 40.0 %, 100.0 % )
# {'MangoJuice', 'Shoes'} => { WaterBottle } ( 40.0 %, 88.88888888888889 % )
# {'WaterBottle', 'Shoes'} => { Onion } ( 40.0 %, 66.66666666666666 % )
# {'Onion', 'WaterBottle'} => { Shoes } ( 40.0 %, 100.0 % )
# {'Onion', 'Shoes'} => { WaterBottle } ( 40.0 %, 80.0 % )
# {'WaterBottle', 'Shoes'} => { Chocolates } ( 45.0 %, 75.0 % )
# {'Chocolates', 'WaterBottle'} => { Shoes } ( 45.0 %, 90.0 % )
# {'Chocolates', 'Shoes'} => { WaterBottle } ( 45.0 %, 90.0 % )
# {'Shorts', 'WaterBottle'} => { Shoes } ( 40.0 %, 88.88888888888889 % )
# {'WaterBottle', 'Shoes'} => { Shorts } ( 40.0 %, 66.66666666666666 % )
# {'Shorts', 'Shoes'} => { WaterBottle } ( 40.0 %, 80.0 % )
# {'WaterBottle', 'Shoes'} => { Lamp } ( 40.0 %, 66.66666666666666 % )
# {'Lamp', 'WaterBottle'} => { Shoes } ( 40.0 %, 88.88888888888889 % )
# {'Lamp', 'Shoes'} => { WaterBottle } ( 40.0 %, 88.88888888888889 % )
# {'Shorts', 'Mouse'} => { Chocolates } ( 40.0 %, 88.88888888888889 % )
# {'Chocolates', 'Shorts'} => { Mouse } ( 40.0 %, 88.88888888888889 % )
# {'Chocolates', 'Mouse'} => { Shorts } ( 40.0 %, 80.0 % )
# Time to execute Apriori Algorithim --- 0.09678053855895996 seconds

# %%
## Executing Apriori Algorithm on Dataset 5
start_time = time.time()
Apriori(.45,.55,"C:/Users/Shank/Desktop/NJIT/CourseMaterial/Spring2022/DataMining/MidTermProject/WorkingDirectory/TransactionDatabase/Database5.csv")
print("Time to execute Apriori Algorithim --- %s seconds" % (time.time() - start_time))
# Out:
# {'Eggs'} => { Bed } ( 50.0 %, 76.92307692307693 % )
# {'Bed'} => { Eggs } ( 50.0 %, 66.66666666666666 % )
# {'Eggs'} => { Banana } ( 45.0 %, 69.23076923076923 % )
# {'Banana'} => { Eggs } ( 45.0 %, 75.0 % )
# {'ShavingCream'} => { Eggs } ( 45.0 %, 90.0 % )
# {'Eggs'} => { ShavingCream } ( 45.0 %, 69.23076923076923 % )
# {'ChickenBreast'} => { Bed } ( 45.0 %, 81.81818181818183 % )
# {'Bed'} => { ChickenBreast } ( 45.0 %, 60.0 % )
# {'Onion'} => { MangoJuice } ( 45.0 %, 75.0 % )
# {'MangoJuice'} => { Onion } ( 45.0 %, 69.23076923076923 % )
# {'Onion'} => { Bed } ( 50.0 %, 83.33333333333334 % )
# {'Bed'} => { Onion } ( 50.0 %, 66.66666666666666 % )
# {'MangoJuice'} => { Bed } ( 50.0 %, 76.92307692307693 % )
# {'Bed'} => { MangoJuice } ( 50.0 %, 66.66666666666666 % )
# {'MangoJuice'} => { Banana } ( 45.0 %, 69.23076923076923 % )
# {'Banana'} => { MangoJuice } ( 45.0 %, 75.0 % )
# {'Shirt'} => { MangoJuice } ( 45.0 %, 64.28571428571429 % )
# {'MangoJuice'} => { Shirt } ( 45.0 %, 69.23076923076923 % )
# {'HardDisk'} => { Bed } ( 50.0 %, 90.9090909090909 % )
# {'Bed'} => { HardDisk } ( 50.0 %, 66.66666666666666 % )
# {'Shirt'} => { HardDisk } ( 45.0 %, 64.28571428571429 % )
# {'HardDisk'} => { Shirt } ( 45.0 %, 81.81818181818183 % )
# {'Pen'} => { Bed } ( 45.0 %, 81.81818181818183 % )
# {'Bed'} => { Pen } ( 45.0 %, 60.0 % )
# {'Bed'} => { Banana } ( 45.0 %, 60.0 % )
# {'Banana'} => { Bed } ( 45.0 %, 75.0 % )
# {'Mouse'} => { Bed } ( 45.0 %, 90.0 % )
# {'Bed'} => { Mouse } ( 45.0 %, 60.0 % )
# {'Moisturizer'} => { Bed } ( 45.0 %, 75.0 % )
# {'Bed'} => { Moisturizer } ( 45.0 %, 60.0 % )
# {'Shirt'} => { Bed } ( 55.00000000000001 %, 78.57142857142857 % )
# {'Bed'} => { Shirt } ( 55.00000000000001 %, 73.33333333333333 % )
# {'Tomato'} => { Bed } ( 45.0 %, 81.81818181818183 % )
# {'Bed'} => { Tomato } ( 45.0 %, 60.0 % )
# {'Pen'} => { Moisturizer } ( 45.0 %, 81.81818181818183 % )
# {'Moisturizer'} => { Pen } ( 45.0 %, 75.0 % )
# {'WetWipes'} => { Banana } ( 45.0 %, 81.81818181818183 % )
# {'Banana'} => { WetWipes } ( 45.0 %, 75.0 % )
# {'Mouse'} => { Moisturizer } ( 45.0 %, 90.0 % )
# {'Moisturizer'} => { Mouse } ( 45.0 %, 75.0 % )
# {'Shirt'} => { Moisturizer } ( 45.0 %, 64.28571428571429 % )
# {'Moisturizer'} => { Shirt } ( 45.0 %, 75.0 % )
# {'Shirt'} => { Lamp } ( 50.0 %, 71.42857142857143 % )
# {'Lamp'} => { Shirt } ( 50.0 %, 83.33333333333334 % )
# Time to execute Apriori Algorithim --- 0.030918359756469727 seconds
