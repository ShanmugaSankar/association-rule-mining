# %%
import pandas as pd
import numpy as np
from itertools import combinations
import time

# %%
def readData(path):
    '''
    Function to read csv file containing the transactions
    
    Parameters:-
    path - Location of the input file
    
    '''
    transactionData = pd.read_csv(path, header = None)
    return transactionData

# %%
def Frequency(transactionData,support):
    '''Fucntion to determine the frequent items in the transaction database
    
    Parameters:-
    transactionData - Single column dataframe containing all the transactions
    support         - User determined support level for generating itemsets
    
    '''
    
    ## Extract transaction information from dataframe to a list
    Transactions = []
    for i in range(len(transactionData)):
        Transactions.append(transactionData[0][i].split(","))
    
    ## Initialize dictionaries to store frequent itemsets
    FrequentItemSets = {}
    AprioriResults = {}
    
    ## Calculate total no. of occurrences of items among all transactions
    for i,items in enumerate(Transactions):
        for j in range(len(items)):
            if items[j] in FrequentItemSets:
                FrequentItemSets[items[j]] += 1
            else:
                FrequentItemSets[items[j]] = 1

    association = []
    nonFrequent = []
    
    ## Assign items to the lists depending on whether they meet the minimum support
    for i in FrequentItemSets:
        if FrequentItemSets[i]/len(Transactions) >= support:
            association.append(i)
        else:
            nonFrequent.append(i)
    
    ## Delete all items which do not meet the minimum support requirement
    for i in nonFrequent:
        del FrequentItemSets[i]

    n_combinations = list(combinations(association,2))
    return n_combinations, FrequentItemSets

# %%
def support_level(n_combinations,support):
    '''
    Function to determine all itemset combinations which meet the minimum support
    
    Parameters:-
    n_combinations - List of all itemset combinations meeting the support requirement
    support        - User determined support level for generating itemsets
    
    '''
    
    ## Loop to generate itemsets as long as they meet support requirements
    while len(n_combinations) > 0:
        itemSets = []
        for i in n_combinations:
            count = 0
            for j in range(len(Transactions)):
                if set(i).issubset(Transactions[j]) == True: ## for itemsets present in transactions, increase count
                     count += 1
            if count/len(Transactions) >= support:           ## if itemset meets minimum support add it to dictionary
                itemSets.append(i)
                AprioriResults[tuple(sorted(i))] = count
         
        addition = []
        ## Loop to generate (n+1)th itemset
        for i in range(len(itemSets)):
            j = len(itemSets) - 1
            while j > i:                                     ## Generating (n+1)th itemset, eg. (A,B),(A,C) => (A,B,C)
                if len(list(set(itemSets[i]) - set(itemSets[j]))) == 1 and set(itemSets[i]).intersection(set(itemSets[j])) != set():
                    addition.append(tuple(set(itemSets[i]).intersection(set(itemSets[j])).union(set(itemSets[i]).symmetric_difference(set(itemSets[j])))))
                j -= 1
        ## List of new itemsets for which support levels need to be checked        
        n_combinations = list(frozenset(sorted(sub)) for sub in set(sorted(addition)))
        
        return AprioriResults

# %%
def confidence_level(AprioriResults,FrequentItemSets,confidence,support):
    '''
    Function to generate the support and confidence levels of itemsets which meet user defined requirements
    
    Parameters:-
    ApriroiResults   -  Dictionary containing frequent itemsets
    FrequentItemSets -  Dictionary containing frequent items
    confidence       -  User determined confidence level for generating itemsets
    support          -  User determined support level for generating itemsets
    
    '''
    ## iterate over itemsets which are greater than minimum support level
    for i,combination in enumerate(AprioriResults):  
    ## iterate to get association of 1 item to the rest of the set
        for j in combination:
            ## for 2-itemsets
            if len(set(combination) - set((j,))) == 1:
                BaseGroup = list(set(combination) - set((j,)),)[0]
                ## calculate support and confidence level
                confidenceCalculation  = AprioriResults.get(combination)/FrequentItemSets.get(BaseGroup)
                supportLevel = AprioriResults.get(combination)/len(Transactions)
                ## print valid associations
                if confidenceCalculation >= confidence and supportLevel >= support:
                    print(set((BaseGroup,)),"=>","{",j,"}","(",supportLevel*100,"%,",confidenceCalculation*100,"%",")")
            ## for n-itemsets, where n > 2
            else:
                BaseGroup = tuple(set(combination) - set((j,)))
                ## calculate support and confidence level
                confidenceCalculation  = AprioriResults.get(combination)/AprioriResults.get(tuple(sorted(BaseGroup)))
                supportLevel = AprioriResults.get(combination)/len(Transactions)
                ## print valid associations
                if confidenceCalculation >= confidence and supportLevel >= support:
                    print(set(BaseGroup),"=>","{",j,"}","(",supportLevel*100,"%,",confidenceCalculation*100,"%",")")
                
            FrequentItemSets[combination] = AprioriResults.get(combination)

# %%
def main(support,confidence,path):
    '''
    Function to execute Apriori Algorithim
    
    Parameters:-
    support     -  User determined support level for generating itemsets
    confidence  -  User determined confidence level for generating itemsets
    path        -  Location of the input file
    
    '''
    
    transactionData = readData(path)
    n_combinations = Frequency(transactionData,support)
    AprioriResults = support_level(n_combinations,support)
    return confidence_level(AprioriResults,FrequentItemSets,confidence,support)

# %%
start_time = time.time()
main(.30,.55,"C:/Users/Shank/Desktop/NJIT/CourseMaterial/Spring2022/DataMining/MidTermProject/WorkingDirectory/TransactionDatabase/Database2.csv")
print("Time to execute Apriori Algorithim --- %s seconds" % (time.time() - start_time))
# Out:
# {'WaterBottle'} => { Tomato } ( 45.0 %, 69.23076923076923 % )
# {'Tomato'} => { WaterBottle } ( 45.0 %, 64.28571428571429 % )
# {'Chocolates'} => { Tomato } ( 30.0 %, 66.66666666666666 % )
# {'Tomato'} => { MangoJuice } ( 45.0 %, 64.28571428571429 % )
# {'MangoJuice'} => { Tomato } ( 45.0 %, 75.0 % )
# {'Tomato'} => { HardDisk } ( 45.0 %, 64.28571428571429 % )
# {'HardDisk'} => { Tomato } ( 45.0 %, 81.81818181818183 % )
# {'Lamp'} => { Tomato } ( 35.0 %, 63.63636363636363 % )
# {'Desk'} => { Tomato } ( 35.0 %, 63.63636363636363 % )
# {'Tomato'} => { Fan } ( 45.0 %, 64.28571428571429 % )
# {'Fan'} => { Tomato } ( 45.0 %, 75.0 % )
# {'Tomato'} => { Pen } ( 40.0 %, 57.14285714285714 % )
# {'Pen'} => { Tomato } ( 40.0 %, 72.72727272727273 % )
# {'Shorts'} => { Tomato } ( 30.0 %, 66.66666666666666 % )
# {'Tomato'} => { Moisturizer } ( 45.0 %, 64.28571428571429 % )
# {'Moisturizer'} => { Tomato } ( 45.0 %, 75.0 % )
# {'Sunscreen'} => { Tomato } ( 35.0 %, 70.0 % )
# {'Tomato'} => { RazerBlades } ( 45.0 %, 64.28571428571429 % )
# {'RazerBlades'} => { Tomato } ( 45.0 %, 75.0 % )
# {'Tomato'} => { Chips } ( 45.0 %, 64.28571428571429 % )
# {'Chips'} => { Tomato } ( 45.0 %, 69.23076923076923 % )
# {'Bed'} => { Tomato } ( 35.0 %, 63.63636363636363 % )
# {'Tomato'} => { Notebook } ( 40.0 %, 57.14285714285714 % )
# {'Notebook'} => { Tomato } ( 40.0 %, 66.66666666666666 % )
# {'Tomato'} => { ShavingCream } ( 50.0 %, 71.42857142857143 % )
# {'ShavingCream'} => { Tomato } ( 50.0 %, 76.92307692307693 % )
# {'Shirt'} => { Tomato } ( 35.0 %, 77.77777777777779 % )
# {'Banana'} => { Tomato } ( 35.0 %, 87.5 % )
# {'Tomato'} => { Shoes } ( 40.0 %, 57.14285714285714 % )
# {'Shoes'} => { Tomato } ( 40.0 %, 72.72727272727273 % )
# {'Milk'} => { HardDisk } ( 30.0 %, 85.71428571428571 % )
# {'Milk'} => { RazerBlades } ( 30.0 %, 85.71428571428571 % )
# {'Chocolates'} => { WaterBottle } ( 30.0 %, 66.66666666666666 % )
# {'WaterBottle'} => { MangoJuice } ( 45.0 %, 69.23076923076923 % )
# {'MangoJuice'} => { WaterBottle } ( 45.0 %, 75.0 % )
# {'Lamp'} => { WaterBottle } ( 35.0 %, 63.63636363636363 % )
# {'WaterBottle'} => { Desk } ( 40.0 %, 61.53846153846154 % )
# {'Desk'} => { WaterBottle } ( 40.0 %, 72.72727272727273 % )
# {'WaterBottle'} => { Pen } ( 40.0 %, 61.53846153846154 % )
# {'Pen'} => { WaterBottle } ( 40.0 %, 72.72727272727273 % )
# {'WaterBottle'} => { Moisturizer } ( 45.0 %, 69.23076923076923 % )
# {'Moisturizer'} => { WaterBottle } ( 45.0 %, 75.0 % )
# {'WaterBottle'} => { Sunscreen } ( 40.0 %, 61.53846153846154 % )
# {'Sunscreen'} => { WaterBottle } ( 40.0 %, 80.0 % )
# {'WaterBottle'} => { RazerBlades } ( 40.0 %, 61.53846153846154 % )
# {'RazerBlades'} => { WaterBottle } ( 40.0 %, 66.66666666666666 % )
# {'WaterBottle'} => { Chips } ( 45.0 %, 69.23076923076923 % )
# {'Chips'} => { WaterBottle } ( 45.0 %, 69.23076923076923 % )
# {'WaterBottle'} => { Bed } ( 40.0 %, 61.53846153846154 % )
# {'Bed'} => { WaterBottle } ( 40.0 %, 72.72727272727273 % )
# {'Umbrella'} => { WaterBottle } ( 30.0 %, 60.0 % )
# {'WaterBottle'} => { Notebook } ( 45.0 %, 69.23076923076923 % )
# {'Notebook'} => { WaterBottle } ( 45.0 %, 75.0 % )
# {'Water'} => { WaterBottle } ( 35.0 %, 70.0 % )
# {'WaterBottle'} => { Eggs } ( 40.0 %, 61.53846153846154 % )
# {'Eggs'} => { WaterBottle } ( 40.0 %, 80.0 % )
# {'ChickenBreast'} => { WaterBottle } ( 30.0 %, 60.0 % )
# {'Shirt'} => { WaterBottle } ( 30.0 %, 66.66666666666666 % )
# {'Shoes'} => { WaterBottle } ( 35.0 %, 63.63636363636363 % )
# {'Chocolates'} => { HardDisk } ( 30.0 %, 66.66666666666666 % )
# {'Chocolates'} => { Fan } ( 30.0 %, 66.66666666666666 % )
# {'Chocolates'} => { Pen } ( 30.0 %, 66.66666666666666 % )
# {'Moisturizer'} => { Chocolates } ( 35.0 %, 58.333333333333336 % )
# {'Chocolates'} => { Moisturizer } ( 35.0 %, 77.77777777777779 % )
# {'Chocolates'} => { RazerBlades } ( 30.0 %, 66.66666666666666 % )
# {'Chocolates'} => { Chips } ( 35.0 %, 77.77777777777779 % )
# {'Eggs'} => { Chocolates } ( 30.0 %, 60.0 % )
# {'Chocolates'} => { Eggs } ( 30.0 %, 66.66666666666666 % )
# {'Mouse'} => { Chocolates } ( 35.0 %, 63.63636363636363 % )
# {'Chocolates'} => { Mouse } ( 35.0 %, 77.77777777777779 % )
# {'MangoJuice'} => { Lamp } ( 40.0 %, 66.66666666666666 % )
# {'Lamp'} => { MangoJuice } ( 40.0 %, 72.72727272727273 % )
# {'MangoJuice'} => { Fan } ( 35.0 %, 58.333333333333336 % )
# {'Fan'} => { MangoJuice } ( 35.0 %, 58.333333333333336 % )
# {'Shorts'} => { MangoJuice } ( 30.0 %, 66.66666666666666 % )
# {'Moisturizer'} => { MangoJuice } ( 40.0 %, 66.66666666666666 % )
# {'MangoJuice'} => { Moisturizer } ( 40.0 %, 66.66666666666666 % )
# {'Sunscreen'} => { MangoJuice } ( 35.0 %, 70.0 % )
# {'MangoJuice'} => { Sunscreen } ( 35.0 %, 58.333333333333336 % )
# {'RazerBlades'} => { MangoJuice } ( 40.0 %, 66.66666666666666 % )
# {'MangoJuice'} => { RazerBlades } ( 40.0 %, 66.66666666666666 % )
# {'MangoJuice'} => { Chips } ( 40.0 %, 66.66666666666666 % )
# {'Chips'} => { MangoJuice } ( 40.0 %, 61.53846153846154 % )
# {'Notebook'} => { MangoJuice } ( 35.0 %, 58.333333333333336 % )
# {'MangoJuice'} => { Notebook } ( 35.0 %, 58.333333333333336 % )
# {'Water'} => { MangoJuice } ( 35.0 %, 70.0 % )
# {'MangoJuice'} => { Water } ( 35.0 %, 58.333333333333336 % )
# {'MangoJuice'} => { ShavingCream } ( 35.0 %, 58.333333333333336 % )
# {'MangoJuice'} => { LightBulb } ( 35.0 %, 58.333333333333336 % )
# {'LightBulb'} => { MangoJuice } ( 35.0 %, 58.333333333333336 % )
# {'Eggs'} => { MangoJuice } ( 30.0 %, 60.0 % )
# {'HardDisk'} => { Fan } ( 40.0 %, 72.72727272727273 % )
# {'Fan'} => { HardDisk } ( 40.0 %, 66.66666666666666 % )
# {'Sunscreen'} => { HardDisk } ( 30.0 %, 60.0 % )
# {'HardDisk'} => { Chips } ( 35.0 %, 63.63636363636363 % )
# {'HardDisk'} => { ShavingCream } ( 35.0 %, 63.63636363636363 % )
# {'Lamp'} => { Fan } ( 35.0 %, 63.63636363636363 % )
# {'Fan'} => { Lamp } ( 35.0 %, 58.333333333333336 % )
# {'Shorts'} => { Lamp } ( 30.0 %, 66.66666666666666 % )
# {'Sunscreen'} => { Lamp } ( 30.0 %, 60.0 % )
# {'RazerBlades'} => { Lamp } ( 35.0 %, 58.333333333333336 % )
# {'Lamp'} => { RazerBlades } ( 35.0 %, 63.63636363636363 % )
# {'Lamp'} => { Chips } ( 40.0 %, 72.72727272727273 % )
# {'Chips'} => { Lamp } ( 40.0 %, 61.53846153846154 % )
# {'Notebook'} => { Lamp } ( 35.0 %, 58.333333333333336 % )
# {'Lamp'} => { Notebook } ( 35.0 %, 63.63636363636363 % )
# {'LightBulb'} => { Lamp } ( 40.0 %, 66.66666666666666 % )
# {'Lamp'} => { LightBulb } ( 40.0 %, 72.72727272727273 % )
# {'Mouse'} => { Lamp } ( 35.0 %, 63.63636363636363 % )
# {'Lamp'} => { Mouse } ( 35.0 %, 63.63636363636363 % )
# {'Shorts'} => { Desk } ( 35.0 %, 77.77777777777779 % )
# {'Desk'} => { Shorts } ( 35.0 %, 63.63636363636363 % )
# {'Moisturizer'} => { Desk } ( 45.0 %, 75.0 % )
# {'Desk'} => { Moisturizer } ( 45.0 %, 81.81818181818183 % )
# {'Sunscreen'} => { Desk } ( 35.0 %, 70.0 % )
# {'Desk'} => { Sunscreen } ( 35.0 %, 63.63636363636363 % )
# {'RazerBlades'} => { Desk } ( 35.0 %, 58.333333333333336 % )
# {'Desk'} => { RazerBlades } ( 35.0 %, 63.63636363636363 % )
# {'Water'} => { Desk } ( 30.0 %, 60.0 % )
# {'Desk'} => { ShavingCream } ( 35.0 %, 63.63636363636363 % )
# {'LightBulb'} => { Desk } ( 35.0 %, 58.333333333333336 % )
# {'Desk'} => { LightBulb } ( 35.0 %, 63.63636363636363 % )
# {'WetWipes'} => { Desk } ( 30.0 %, 75.0 % )
# {'Eggs'} => { Desk } ( 35.0 %, 70.0 % )
# {'Desk'} => { Eggs } ( 35.0 %, 63.63636363636363 % )
# {'Pen'} => { Fan } ( 35.0 %, 63.63636363636363 % )
# {'Fan'} => { Pen } ( 35.0 %, 58.333333333333336 % )
# {'Sunscreen'} => { Fan } ( 35.0 %, 70.0 % )
# {'Fan'} => { Sunscreen } ( 35.0 %, 58.333333333333336 % )
# {'Fan'} => { Chips } ( 35.0 %, 58.333333333333336 % )
# {'Umbrella'} => { Fan } ( 30.0 %, 60.0 % )
# {'ShavingCream'} => { Fan } ( 40.0 %, 61.53846153846154 % )
# {'Fan'} => { ShavingCream } ( 40.0 %, 66.66666666666666 % )
# {'LightBulb'} => { Fan } ( 35.0 %, 58.333333333333336 % )
# {'Fan'} => { LightBulb } ( 35.0 %, 58.333333333333336 % )
# {'Fan'} => { ChickenBreast } ( 35.0 %, 58.333333333333336 % )
# {'ChickenBreast'} => { Fan } ( 35.0 %, 70.0 % )
# {'Banana'} => { Fan } ( 30.0 %, 75.0 % )
# {'Shoes'} => { Fan } ( 40.0 %, 72.72727272727273 % )
# {'Fan'} => { Shoes } ( 40.0 %, 66.66666666666666 % )
# {'Mouse'} => { Fan } ( 35.0 %, 63.63636363636363 % )
# {'Fan'} => { Mouse } ( 35.0 %, 58.333333333333336 % )
# {'Sunscreen'} => { Pen } ( 30.0 %, 60.0 % )
# {'Pen'} => { Notebook } ( 35.0 %, 63.63636363636363 % )
# {'Notebook'} => { Pen } ( 35.0 %, 58.333333333333336 % )
# {'Pen'} => { ShavingCream } ( 35.0 %, 63.63636363636363 % )
# {'ChickenBreast'} => { Pen } ( 30.0 %, 60.0 % )
# {'Shirt'} => { Pen } ( 35.0 %, 77.77777777777779 % )
# {'Pen'} => { Shirt } ( 35.0 %, 63.63636363636363 % )
# {'Shorts'} => { Moisturizer } ( 30.0 %, 66.66666666666666 % )
# {'Shorts'} => { ShavingCream } ( 30.0 %, 66.66666666666666 % )
# {'Shorts'} => { LightBulb } ( 30.0 %, 66.66666666666666 % )
# {'Sunscreen'} => { Moisturizer } ( 30.0 %, 60.0 % )
# {'RazerBlades'} => { Moisturizer } ( 45.0 %, 75.0 % )
# {'Moisturizer'} => { RazerBlades } ( 45.0 %, 75.0 % )
# {'Moisturizer'} => { Chips } ( 40.0 %, 66.66666666666666 % )
# {'Chips'} => { Moisturizer } ( 40.0 %, 61.53846153846154 % )
# {'Umbrella'} => { Moisturizer } ( 30.0 %, 60.0 % )
# {'Notebook'} => { Moisturizer } ( 40.0 %, 66.66666666666666 % )
# {'Moisturizer'} => { Notebook } ( 40.0 %, 66.66666666666666 % )
# {'Moisturizer'} => { ShavingCream } ( 35.0 %, 58.333333333333336 % )
# {'Moisturizer'} => { LightBulb } ( 35.0 %, 58.333333333333336 % )
# {'LightBulb'} => { Moisturizer } ( 35.0 %, 58.333333333333336 % )
# {'WetWipes'} => { Moisturizer } ( 35.0 %, 87.5 % )
# {'Moisturizer'} => { WetWipes } ( 35.0 %, 58.333333333333336 % )
# {'Moisturizer'} => { Eggs } ( 40.0 %, 66.66666666666666 % )
# {'Eggs'} => { Moisturizer } ( 40.0 %, 80.0 % )
# {'ChickenBreast'} => { Moisturizer } ( 30.0 %, 60.0 % )
# {'Shoes'} => { Moisturizer } ( 35.0 %, 63.63636363636363 % )
# {'Moisturizer'} => { Shoes } ( 35.0 %, 58.333333333333336 % )
# {'Sunscreen'} => { Notebook } ( 30.0 %, 60.0 % )
# {'Sunscreen'} => { ShavingCream } ( 30.0 %, 60.0 % )
# {'Sunscreen'} => { Eggs } ( 30.0 %, 60.0 % )
# {'Eggs'} => { Sunscreen } ( 30.0 %, 60.0 % )
# {'Sunscreen'} => { Banana } ( 30.0 %, 60.0 % )
# {'Banana'} => { Sunscreen } ( 30.0 %, 75.0 % )
# {'RazerBlades'} => { Chips } ( 40.0 %, 66.66666666666666 % )
# {'Chips'} => { RazerBlades } ( 40.0 %, 61.53846153846154 % )
# {'RazerBlades'} => { Bed } ( 40.0 %, 66.66666666666666 % )
# {'Bed'} => { RazerBlades } ( 40.0 %, 72.72727272727273 % )
# {'RazerBlades'} => { Notebook } ( 45.0 %, 75.0 % )
# {'Notebook'} => { RazerBlades } ( 45.0 %, 75.0 % )
# {'Water'} => { RazerBlades } ( 30.0 %, 60.0 % )
# {'ShavingCream'} => { RazerBlades } ( 40.0 %, 61.53846153846154 % )
# {'RazerBlades'} => { ShavingCream } ( 40.0 %, 66.66666666666666 % )
# {'RazerBlades'} => { Onion } ( 35.0 %, 58.333333333333336 % )
# {'Onion'} => { RazerBlades } ( 35.0 %, 87.5 % )
# {'RazerBlades'} => { Eggs } ( 35.0 %, 58.333333333333336 % )
# {'Eggs'} => { RazerBlades } ( 35.0 %, 70.0 % )
# {'ChickenBreast'} => { RazerBlades } ( 30.0 %, 60.0 % )
# {'Shirt'} => { RazerBlades } ( 30.0 %, 66.66666666666666 % )
# {'Shoes'} => { RazerBlades } ( 35.0 %, 63.63636363636363 % )
# {'RazerBlades'} => { Shoes } ( 35.0 %, 58.333333333333336 % )
# {'RazerBlades'} => { Mouse } ( 35.0 %, 58.333333333333336 % )
# {'Mouse'} => { RazerBlades } ( 35.0 %, 63.63636363636363 % )
# {'Chips'} => { Bed } ( 40.0 %, 61.53846153846154 % )
# {'Bed'} => { Chips } ( 40.0 %, 72.72727272727273 % )
# {'Umbrella'} => { Chips } ( 35.0 %, 70.0 % )
# {'Notebook'} => { Chips } ( 45.0 %, 75.0 % )
# {'Chips'} => { Notebook } ( 45.0 %, 69.23076923076923 % )
# {'Water'} => { Chips } ( 40.0 %, 80.0 % )
# {'Chips'} => { Water } ( 40.0 %, 61.53846153846154 % )
# {'LightBulb'} => { Chips } ( 40.0 %, 66.66666666666666 % )
# {'Chips'} => { LightBulb } ( 40.0 %, 61.53846153846154 % )
# {'Eggs'} => { Chips } ( 35.0 %, 70.0 % )
# {'Mouse'} => { Chips } ( 40.0 %, 72.72727272727273 % )
# {'Chips'} => { Mouse } ( 40.0 %, 61.53846153846154 % )
# {'Notebook'} => { Bed } ( 45.0 %, 75.0 % )
# {'Bed'} => { Notebook } ( 45.0 %, 81.81818181818183 % )
# {'Water'} => { Bed } ( 35.0 %, 70.0 % )
# {'Bed'} => { Water } ( 35.0 %, 63.63636363636363 % )
# {'ShavingCream'} => { Bed } ( 40.0 %, 61.53846153846154 % )
# {'Bed'} => { ShavingCream } ( 40.0 %, 72.72727272727273 % )
# {'WetWipes'} => { Bed } ( 30.0 %, 75.0 % )
# {'Eggs'} => { Bed } ( 30.0 %, 60.0 % )
# {'ChickenBreast'} => { Bed } ( 35.0 %, 70.0 % )
# {'Bed'} => { ChickenBreast } ( 35.0 %, 63.63636363636363 % )
# {'Umbrella'} => { Notebook } ( 30.0 %, 60.0 % )
# {'Water'} => { Umbrella } ( 30.0 %, 60.0 % )
# {'Umbrella'} => { Water } ( 30.0 %, 60.0 % )
# {'Umbrella'} => { ShavingCream } ( 40.0 %, 80.0 % )
# {'ShavingCream'} => { Umbrella } ( 40.0 %, 61.53846153846154 % )
# {'Umbrella'} => { LightBulb } ( 30.0 %, 60.0 % )
# {'Umbrella'} => { Eggs } ( 35.0 %, 70.0 % )
# {'Eggs'} => { Umbrella } ( 35.0 %, 70.0 % )
# {'Umbrella'} => { ChickenBreast } ( 30.0 %, 60.0 % )
# {'ChickenBreast'} => { Umbrella } ( 30.0 %, 60.0 % )
# {'Umbrella'} => { Mouse } ( 40.0 %, 80.0 % )
# {'Mouse'} => { Umbrella } ( 40.0 %, 72.72727272727273 % )
# {'Heater'} => { ShavingCream } ( 30.0 %, 100.0 % )
# {'Water'} => { Notebook } ( 35.0 %, 70.0 % )
# {'Notebook'} => { Water } ( 35.0 %, 58.333333333333336 % )
# {'Notebook'} => { ShavingCream } ( 35.0 %, 58.333333333333336 % )
# {'Onion'} => { Notebook } ( 30.0 %, 75.0 % )
# {'Notebook'} => { LightBulb } ( 35.0 %, 58.333333333333336 % )
# {'LightBulb'} => { Notebook } ( 35.0 %, 58.333333333333336 % )
# {'WetWipes'} => { Notebook } ( 35.0 %, 87.5 % )
# {'Notebook'} => { WetWipes } ( 35.0 %, 58.333333333333336 % )
# {'Notebook'} => { Eggs } ( 40.0 %, 66.66666666666666 % )
# {'Eggs'} => { Notebook } ( 40.0 %, 80.0 % )
# {'ChickenBreast'} => { Notebook } ( 30.0 %, 60.0 % )
# {'Shirt'} => { Notebook } ( 30.0 %, 66.66666666666666 % )
# {'Shoes'} => { Notebook } ( 40.0 %, 72.72727272727273 % )
# {'Notebook'} => { Shoes } ( 40.0 %, 66.66666666666666 % )
# {'Notebook'} => { Mouse } ( 35.0 %, 58.333333333333336 % )
# {'Mouse'} => { Notebook } ( 35.0 %, 63.63636363636363 % )
# {'Water'} => { ShavingCream } ( 30.0 %, 60.0 % )
# {'Water'} => { LightBulb } ( 35.0 %, 70.0 % )
# {'LightBulb'} => { Water } ( 35.0 %, 58.333333333333336 % )
# {'Water'} => { Eggs } ( 30.0 %, 60.0 % )
# {'Eggs'} => { Water } ( 30.0 %, 60.0 % )
# {'Water'} => { Mouse } ( 30.0 %, 60.0 % )
# {'Onion'} => { ShavingCream } ( 30.0 %, 75.0 % )
# {'Eggs'} => { ShavingCream } ( 30.0 %, 60.0 % )
# {'ChickenBreast'} => { ShavingCream } ( 35.0 %, 70.0 % )
# {'Shirt'} => { ShavingCream } ( 35.0 %, 77.77777777777779 % )
# {'Shoes'} => { ShavingCream } ( 35.0 %, 63.63636363636363 % )
# {'Mouse'} => { ShavingCream } ( 35.0 %, 63.63636363636363 % )
# {'Onion'} => { LightBulb } ( 30.0 %, 75.0 % )
# {'Onion'} => { Shoes } ( 30.0 %, 75.0 % )
# {'WetWipes'} => { LightBulb } ( 30.0 %, 75.0 % )
# {'Eggs'} => { LightBulb } ( 30.0 %, 60.0 % )
# {'LightBulb'} => { ChickenBreast } ( 35.0 %, 58.333333333333336 % )
# {'ChickenBreast'} => { LightBulb } ( 35.0 %, 70.0 % )
# {'Shoes'} => { LightBulb } ( 35.0 %, 63.63636363636363 % )
# {'LightBulb'} => { Shoes } ( 35.0 %, 58.333333333333336 % )
# {'Mouse'} => { LightBulb } ( 40.0 %, 72.72727272727273 % )
# {'LightBulb'} => { Mouse } ( 40.0 %, 66.66666666666666 % )
# {'WetWipes'} => { Eggs } ( 30.0 %, 75.0 % )
# {'Eggs'} => { WetWipes } ( 30.0 %, 60.0 % )
# {'WetWipes'} => { ChickenBreast } ( 30.0 %, 75.0 % )
# {'ChickenBreast'} => { WetWipes } ( 30.0 %, 60.0 % )
# {'WetWipes'} => { Shoes } ( 30.0 %, 75.0 % )
# {'Eggs'} => { ChickenBreast } ( 30.0 %, 60.0 % )
# {'ChickenBreast'} => { Eggs } ( 30.0 %, 60.0 % )
# {'Eggs'} => { Shoes } ( 30.0 %, 60.0 % )
# {'Mouse'} => { Eggs } ( 40.0 %, 72.72727272727273 % )
# {'Eggs'} => { Mouse } ( 40.0 %, 80.0 % )
# {'Shoes'} => { ChickenBreast } ( 40.0 %, 72.72727272727273 % )
# {'ChickenBreast'} => { Shoes } ( 40.0 %, 80.0 % )
# {'ChickenBreast'} => { Mouse } ( 30.0 %, 60.0 % )
# {'Shirt'} => { Shoes } ( 30.0 %, 66.66666666666666 % )
# {'Shirt'} => { Mouse } ( 30.0 %, 66.66666666666666 % )
# {'Banana'} => { Shoes } ( 30.0 %, 75.0 % )
# {'Shoes'} => { Mouse } ( 35.0 %, 63.63636363636363 % )
# {'Mouse'} => { Shoes } ( 35.0 %, 63.63636363636363 % )
# {'WaterBottle', 'Notebook'} => { Chips } ( 30.0 %, 66.66666666666666 % )
# {'Chips', 'WaterBottle'} => { Notebook } ( 30.0 %, 66.66666666666666 % )
# {'Chips', 'Notebook'} => { WaterBottle } ( 30.0 %, 66.66666666666666 % )
# {'Pen', 'Shirt'} => { Notebook } ( 30.0 %, 85.71428571428571 % )
# {'Notebook', 'Shirt'} => { Pen } ( 30.0 %, 100.0 % )
# {'Pen', 'Notebook'} => { Shirt } ( 30.0 %, 85.71428571428571 % )
# {'Shoes', 'WetWipes'} => { ChickenBreast } ( 30.0 %, 100.0 % )
# {'ChickenBreast', 'WetWipes'} => { Shoes } ( 30.0 %, 100.0 % )
# {'ChickenBreast', 'Shoes'} => { WetWipes } ( 30.0 %, 75.0 % )
# {'Moisturizer', 'Shoes'} => { ChickenBreast } ( 30.0 %, 85.71428571428571 % )
# {'ChickenBreast', 'Shoes'} => { Moisturizer } ( 30.0 %, 75.0 % )
# {'Moisturizer', 'ChickenBreast'} => { Shoes } ( 30.0 %, 100.0 % )
# {'ChickenBreast', 'Shoes'} => { Bed } ( 30.0 %, 75.0 % )
# {'Bed', 'Shoes'} => { ChickenBreast } ( 30.0 %, 100.0 % )
# {'Bed', 'ChickenBreast'} => { Shoes } ( 30.0 %, 85.71428571428571 % )
# {'Tomato', 'ShavingCream'} => { Chips } ( 30.0 %, 60.0 % )
# {'Chips', 'Tomato'} => { ShavingCream } ( 30.0 %, 66.66666666666666 % )
# {'Chips', 'ShavingCream'} => { Tomato } ( 30.0 %, 85.71428571428571 % )
# {'RazerBlades', 'Notebook'} => { Bed } ( 35.0 %, 77.77777777777779 % )
# {'Bed', 'RazerBlades'} => { Notebook } ( 35.0 %, 87.5 % )
# {'Bed', 'Notebook'} => { RazerBlades } ( 35.0 %, 77.77777777777779 % )
# {'WaterBottle', 'Sunscreen'} => { MangoJuice } ( 35.0 %, 87.5 % )
# {'MangoJuice', 'WaterBottle'} => { Sunscreen } ( 35.0 %, 77.77777777777779 % )
# {'MangoJuice', 'Sunscreen'} => { WaterBottle } ( 35.0 %, 100.0 % )
# {'MangoJuice', 'WaterBottle'} => { Chips } ( 30.0 %, 66.66666666666666 % )
# {'Chips', 'WaterBottle'} => { MangoJuice } ( 30.0 %, 66.66666666666666 % )
# {'Chips', 'MangoJuice'} => { WaterBottle } ( 30.0 %, 75.0 % )
# {'HardDisk', 'Notebook'} => { Chips } ( 30.0 %, 100.0 % )
# {'Chips', 'Notebook'} => { HardDisk } ( 30.0 %, 66.66666666666666 % )
# {'Chips', 'HardDisk'} => { Notebook } ( 30.0 %, 85.71428571428571 % )
# {'RazerBlades', 'Tomato'} => { Notebook } ( 35.0 %, 77.77777777777779 % )
# {'Notebook', 'Tomato'} => { RazerBlades } ( 35.0 %, 87.5 % )
# {'RazerBlades', 'Notebook'} => { Tomato } ( 35.0 %, 77.77777777777779 % )
# {'MangoJuice', 'LightBulb'} => { Lamp } ( 30.0 %, 85.71428571428571 % )
# {'MangoJuice', 'Lamp'} => { LightBulb } ( 30.0 %, 75.0 % )
# {'Lamp', 'LightBulb'} => { MangoJuice } ( 30.0 %, 75.0 % )
# {'Eggs', 'Notebook'} => { Chips } ( 30.0 %, 75.0 % )
# {'Chips', 'Notebook'} => { Eggs } ( 30.0 %, 66.66666666666666 % )
# {'Chips', 'Eggs'} => { Notebook } ( 30.0 %, 85.71428571428571 % )
# {'Tomato', 'ShavingCream'} => { Fan } ( 30.0 %, 60.0 % )
# {'Fan', 'Tomato'} => { ShavingCream } ( 30.0 %, 66.66666666666666 % )
# {'Fan', 'ShavingCream'} => { Tomato } ( 30.0 %, 75.0 % )
# {'Chips', 'Water'} => { Bed } ( 30.0 %, 75.0 % )
# {'Bed', 'Water'} => { Chips } ( 30.0 %, 85.71428571428571 % )
# {'Bed', 'Chips'} => { Water } ( 30.0 %, 75.0 % )
# {'Moisturizer', 'WaterBottle'} => { Chips } ( 30.0 %, 66.66666666666666 % )
# {'Chips', 'WaterBottle'} => { Moisturizer } ( 30.0 %, 66.66666666666666 % )
# {'Moisturizer', 'Chips'} => { WaterBottle } ( 30.0 %, 75.0 % )
# {'WaterBottle', 'Notebook'} => { Bed } ( 35.0 %, 77.77777777777779 % )
# {'Bed', 'WaterBottle'} => { Notebook } ( 35.0 %, 87.5 % )
# {'Bed', 'Notebook'} => { WaterBottle } ( 35.0 %, 77.77777777777779 % )
# {'Moisturizer', 'RazerBlades'} => { Desk } ( 35.0 %, 77.77777777777779 % )
# {'Desk', 'RazerBlades'} => { Moisturizer } ( 35.0 %, 100.0 % )
# {'Moisturizer', 'Desk'} => { RazerBlades } ( 35.0 %, 77.77777777777779 % )
# {'Moisturizer', 'RazerBlades'} => { MangoJuice } ( 30.0 %, 66.66666666666666 % )
# {'MangoJuice', 'RazerBlades'} => { Moisturizer } ( 30.0 %, 75.0 % )
# {'Moisturizer', 'MangoJuice'} => { RazerBlades } ( 30.0 %, 75.0 % )
# {'Chips', 'Notebook'} => { Bed } ( 30.0 %, 66.66666666666666 % )
# {'Bed', 'Notebook'} => { Chips } ( 30.0 %, 66.66666666666666 % )
# {'Bed', 'Chips'} => { Notebook } ( 30.0 %, 75.0 % )
# {'Moisturizer', 'Tomato'} => { Desk } ( 30.0 %, 66.66666666666666 % )
# {'Desk', 'Tomato'} => { Moisturizer } ( 30.0 %, 85.71428571428571 % )
# {'Moisturizer', 'Desk'} => { Tomato } ( 30.0 %, 66.66666666666666 % )
# {'WaterBottle', 'Notebook'} => { Moisturizer } ( 30.0 %, 66.66666666666666 % )
# {'Moisturizer', 'WaterBottle'} => { Notebook } ( 30.0 %, 66.66666666666666 % )
# {'Moisturizer', 'Notebook'} => { WaterBottle } ( 30.0 %, 75.0 % )
# {'Tomato', 'ShavingCream'} => { MangoJuice } ( 30.0 %, 60.0 % )
# {'MangoJuice', 'Tomato'} => { ShavingCream } ( 30.0 %, 66.66666666666666 % )
# {'MangoJuice', 'ShavingCream'} => { Tomato } ( 30.0 %, 85.71428571428571 % )
# {'HardDisk', 'Tomato'} => { Chips } ( 30.0 %, 66.66666666666666 % )
# {'Chips', 'Tomato'} => { HardDisk } ( 30.0 %, 66.66666666666666 % )
# {'Chips', 'HardDisk'} => { Tomato } ( 30.0 %, 85.71428571428571 % )
# {'Tomato', 'ShavingCream'} => { RazerBlades } ( 30.0 %, 60.0 % )
# {'RazerBlades', 'Tomato'} => { ShavingCream } ( 30.0 %, 66.66666666666666 % )
# {'RazerBlades', 'ShavingCream'} => { Tomato } ( 30.0 %, 75.0 % )
# {'MangoJuice', 'LightBulb'} => { Chips } ( 30.0 %, 85.71428571428571 % )
# {'Chips', 'MangoJuice'} => { LightBulb } ( 30.0 %, 75.0 % )
# {'Chips', 'LightBulb'} => { MangoJuice } ( 30.0 %, 75.0 % )
# {'RazerBlades', 'Tomato'} => { MangoJuice } ( 35.0 %, 77.77777777777779 % )
# {'MangoJuice', 'Tomato'} => { RazerBlades } ( 35.0 %, 77.77777777777779 % )
# {'MangoJuice', 'RazerBlades'} => { Tomato } ( 35.0 %, 87.5 % )
# {'Tomato', 'ShavingCream'} => { Moisturizer } ( 30.0 %, 60.0 % )
# {'Moisturizer', 'Tomato'} => { ShavingCream } ( 30.0 %, 66.66666666666666 % )
# {'Moisturizer', 'ShavingCream'} => { Tomato } ( 30.0 %, 85.71428571428571 % )
# {'Water', 'Notebook'} => { Bed } ( 30.0 %, 85.71428571428571 % )
# {'Bed', 'Water'} => { Notebook } ( 30.0 %, 85.71428571428571 % )
# {'Bed', 'Notebook'} => { Water } ( 30.0 %, 66.66666666666666 % )
# {'Lamp', 'Tomato'} => { HardDisk } ( 30.0 %, 85.71428571428571 % )
# {'HardDisk', 'Tomato'} => { Lamp } ( 30.0 %, 66.66666666666666 % )
# {'HardDisk', 'Lamp'} => { Tomato } ( 30.0 %, 100.0 % )
# {'Mouse', 'LightBulb'} => { Lamp } ( 30.0 %, 75.0 % )
# {'Lamp', 'Mouse'} => { LightBulb } ( 30.0 %, 85.71428571428571 % )
# {'Lamp', 'LightBulb'} => { Mouse } ( 30.0 %, 75.0 % )
# {'Moisturizer', 'WaterBottle'} => { MangoJuice } ( 35.0 %, 77.77777777777779 % )
# {'MangoJuice', 'WaterBottle'} => { Moisturizer } ( 35.0 %, 77.77777777777779 % )
# {'Moisturizer', 'MangoJuice'} => { WaterBottle } ( 35.0 %, 87.5 % )
# {'Pen', 'Tomato'} => { Fan } ( 30.0 %, 75.0 % )
# {'Fan', 'Tomato'} => { Pen } ( 30.0 %, 66.66666666666666 % )
# {'Pen', 'Fan'} => { Tomato } ( 30.0 %, 85.71428571428571 % )
# {'RazerBlades', 'Notebook'} => { Moisturizer } ( 35.0 %, 77.77777777777779 % )
# {'Moisturizer', 'RazerBlades'} => { Notebook } ( 35.0 %, 77.77777777777779 % )
# {'Moisturizer', 'Notebook'} => { RazerBlades } ( 35.0 %, 87.5 % )
# {'WaterBottle', 'Tomato'} => { Moisturizer } ( 30.0 %, 66.66666666666666 % )
# {'Moisturizer', 'WaterBottle'} => { Tomato } ( 30.0 %, 66.66666666666666 % )
# {'Moisturizer', 'Tomato'} => { WaterBottle } ( 30.0 %, 66.66666666666666 % )
# {'WaterBottle', 'Water'} => { Chips } ( 30.0 %, 85.71428571428571 % )
# {'Chips', 'WaterBottle'} => { Water } ( 30.0 %, 66.66666666666666 % )
# {'Chips', 'Water'} => { WaterBottle } ( 30.0 %, 75.0 % )
# {'WaterBottle', 'Water'} => { Notebook } ( 30.0 %, 85.71428571428571 % )
# {'WaterBottle', 'Notebook'} => { Water } ( 30.0 %, 66.66666666666666 % )
# {'Water', 'Notebook'} => { WaterBottle } ( 30.0 %, 85.71428571428571 % )
# {'MangoJuice', 'WaterBottle'} => { Eggs } ( 30.0 %, 66.66666666666666 % )
# {'WaterBottle', 'Eggs'} => { MangoJuice } ( 30.0 %, 75.0 % )
# {'MangoJuice', 'Eggs'} => { WaterBottle } ( 30.0 %, 100.0 % )
# {'Umbrella', 'ShavingCream'} => { Mouse } ( 30.0 %, 75.0 % )
# {'Umbrella', 'Mouse'} => { ShavingCream } ( 30.0 %, 75.0 % )
# {'ShavingCream', 'Mouse'} => { Umbrella } ( 30.0 %, 85.71428571428571 % )
# {'Shoes', 'Notebook'} => { Mouse } ( 30.0 %, 75.0 % )
# {'Shoes', 'Mouse'} => { Notebook } ( 30.0 %, 85.71428571428571 % )
# {'Notebook', 'Mouse'} => { Shoes } ( 30.0 %, 85.71428571428571 % )
# {'RazerBlades', 'ShavingCream'} => { Moisturizer } ( 30.0 %, 75.0 % )
# {'Moisturizer', 'ShavingCream'} => { RazerBlades } ( 30.0 %, 85.71428571428571 % )
# {'Moisturizer', 'RazerBlades'} => { ShavingCream } ( 30.0 %, 66.66666666666666 % )
# {'Moisturizer', 'LightBulb'} => { Desk } ( 30.0 %, 85.71428571428571 % )
# {'Moisturizer', 'Desk'} => { LightBulb } ( 30.0 %, 66.66666666666666 % )
# {'Desk', 'LightBulb'} => { Moisturizer } ( 30.0 %, 85.71428571428571 % )
# {'RazerBlades', 'ShavingCream'} => { Notebook } ( 30.0 %, 75.0 % )
# {'Notebook', 'ShavingCream'} => { RazerBlades } ( 30.0 %, 85.71428571428571 % )
# {'RazerBlades', 'Notebook'} => { ShavingCream } ( 30.0 %, 66.66666666666666 % )
# {'RazerBlades', 'Tomato'} => { Moisturizer } ( 35.0 %, 77.77777777777779 % )
# {'Moisturizer', 'Tomato'} => { RazerBlades } ( 35.0 %, 77.77777777777779 % )
# {'Moisturizer', 'RazerBlades'} => { Tomato } ( 35.0 %, 77.77777777777779 % )
# {'WaterBottle', 'Mouse'} => { Eggs } ( 30.0 %, 100.0 % )
# {'WaterBottle', 'Eggs'} => { Mouse } ( 30.0 %, 75.0 % )
# {'Eggs', 'Mouse'} => { WaterBottle } ( 30.0 %, 75.0 % )
# {'Sunscreen', 'Notebook'} => { MangoJuice } ( 30.0 %, 100.0 % )
# {'MangoJuice', 'Sunscreen'} => { Notebook } ( 30.0 %, 85.71428571428571 % )
# {'MangoJuice', 'Notebook'} => { Sunscreen } ( 30.0 %, 85.71428571428571 % )
# {'ChickenBreast', 'RazerBlades'} => { Bed } ( 30.0 %, 100.0 % )
# {'Bed', 'RazerBlades'} => { ChickenBreast } ( 30.0 %, 75.0 % )
# {'Bed', 'ChickenBreast'} => { RazerBlades } ( 30.0 %, 85.71428571428571 % )
# {'Water', 'Notebook'} => { Chips } ( 30.0 %, 85.71428571428571 % )
# {'Chips', 'Water'} => { Notebook } ( 30.0 %, 75.0 % )
# {'Chips', 'Notebook'} => { Water } ( 30.0 %, 66.66666666666666 % )
# {'WaterBottle', 'Eggs'} => { Desk } ( 30.0 %, 75.0 % )
# {'WaterBottle', 'Desk'} => { Eggs } ( 30.0 %, 75.0 % )
# {'Desk', 'Eggs'} => { WaterBottle } ( 30.0 %, 85.71428571428571 % )
# {'Moisturizer', 'Notebook'} => { Bed } ( 30.0 %, 75.0 % )
# {'Bed', 'Notebook'} => { Moisturizer } ( 30.0 %, 66.66666666666666 % )
# {'Moisturizer', 'Bed'} => { Notebook } ( 30.0 %, 100.0 % )
# {'Tomato', 'ShavingCream'} => { HardDisk } ( 30.0 %, 60.0 % )
# {'HardDisk', 'Tomato'} => { ShavingCream } ( 30.0 %, 66.66666666666666 % )
# {'HardDisk', 'ShavingCream'} => { Tomato } ( 30.0 %, 85.71428571428571 % )
# {'Lamp', 'Notebook'} => { Chips } ( 30.0 %, 85.71428571428571 % )
# {'Chips', 'Notebook'} => { Lamp } ( 30.0 %, 66.66666666666666 % )
# {'Chips', 'Lamp'} => { Notebook } ( 30.0 %, 75.0 % )
# {'Notebook', 'WetWipes'} => { Moisturizer } ( 30.0 %, 85.71428571428571 % )
# {'Moisturizer', 'WetWipes'} => { Notebook } ( 30.0 %, 85.71428571428571 % )
# {'Moisturizer', 'Notebook'} => { WetWipes } ( 30.0 %, 75.0 % )
# {'HardDisk', 'ShavingCream'} => { Fan } ( 30.0 %, 85.71428571428571 % )
# {'Fan', 'ShavingCream'} => { HardDisk } ( 30.0 %, 75.0 % )
# {'HardDisk', 'Fan'} => { ShavingCream } ( 30.0 %, 75.0 % )
# {'WaterBottle', 'RazerBlades'} => { Notebook } ( 30.0 %, 75.0 % )
# {'WaterBottle', 'Notebook'} => { RazerBlades } ( 30.0 %, 66.66666666666666 % )
# {'RazerBlades', 'Notebook'} => { WaterBottle } ( 30.0 %, 66.66666666666666 % )
# {'HardDisk', 'Tomato'} => { Fan } ( 35.0 %, 77.77777777777779 % )
# {'Fan', 'Tomato'} => { HardDisk } ( 35.0 %, 77.77777777777779 % )
# {'HardDisk', 'Fan'} => { Tomato } ( 35.0 %, 87.5 % )
# {'Moisturizer', 'Eggs'} => { Chips } ( 30.0 %, 75.0 % )
# {'Moisturizer', 'Chips'} => { Eggs } ( 30.0 %, 75.0 % )
# {'Chips', 'Eggs'} => { Moisturizer } ( 30.0 %, 85.71428571428571 % )
# {'Moisturizer', 'Tomato'} => { MangoJuice } ( 35.0 %, 77.77777777777779 % )
# {'MangoJuice', 'Tomato'} => { Moisturizer } ( 35.0 %, 77.77777777777779 % )
# {'Moisturizer', 'MangoJuice'} => { Tomato } ( 35.0 %, 87.5 % )
# {'RazerBlades', 'ShavingCream'} => { Bed } ( 30.0 %, 75.0 % )
# {'Bed', 'ShavingCream'} => { RazerBlades } ( 30.0 %, 75.0 % )
# {'Bed', 'RazerBlades'} => { ShavingCream } ( 30.0 %, 75.0 % )
# {'WaterBottle', 'RazerBlades'} => { Eggs } ( 30.0 %, 75.0 % )
# {'WaterBottle', 'Eggs'} => { RazerBlades } ( 30.0 %, 75.0 % )
# {'Eggs', 'RazerBlades'} => { WaterBottle } ( 30.0 %, 85.71428571428571 % )
# {'Shirt', 'Tomato'} => { ShavingCream } ( 30.0 %, 85.71428571428571 % )
# {'Tomato', 'ShavingCream'} => { Shirt } ( 30.0 %, 60.0 % )
# {'Shirt', 'ShavingCream'} => { Tomato } ( 30.0 %, 85.71428571428571 % )
# {'WaterBottle', 'Notebook'} => { MangoJuice } ( 30.0 %, 66.66666666666666 % )
# {'MangoJuice', 'WaterBottle'} => { Notebook } ( 30.0 %, 66.66666666666666 % )
# {'MangoJuice', 'Notebook'} => { WaterBottle } ( 30.0 %, 85.71428571428571 % )
# {'Moisturizer', 'Notebook'} => { Chips } ( 30.0 %, 75.0 % )
# {'Chips', 'Notebook'} => { Moisturizer } ( 30.0 %, 66.66666666666666 % )
# {'Moisturizer', 'Chips'} => { Notebook } ( 30.0 %, 75.0 % )
# {'RazerBlades', 'ShavingCream'} => { MangoJuice } ( 30.0 %, 75.0 % )
# {'MangoJuice', 'ShavingCream'} => { RazerBlades } ( 30.0 %, 85.71428571428571 % )
# {'MangoJuice', 'RazerBlades'} => { ShavingCream } ( 30.0 %, 75.0 % )
# {'Tomato', 'ShavingCream'} => { Notebook } ( 30.0 %, 60.0 % )
# {'Notebook', 'Tomato'} => { ShavingCream } ( 30.0 %, 75.0 % )
# {'Notebook', 'ShavingCream'} => { Tomato } ( 30.0 %, 85.71428571428571 % )
# {'Moisturizer', 'RazerBlades'} => { Bed } ( 30.0 %, 66.66666666666666 % )
# {'Bed', 'RazerBlades'} => { Moisturizer } ( 30.0 %, 75.0 % )
# {'Moisturizer', 'Bed'} => { RazerBlades } ( 30.0 %, 100.0 % )
# {'Shoes', 'WaterBottle'} => { ChickenBreast } ( 30.0 %, 85.71428571428571 % )
# {'ChickenBreast', 'WaterBottle'} => { Shoes } ( 30.0 %, 100.0 % )
# {'ChickenBreast', 'Shoes'} => { WaterBottle } ( 30.0 %, 75.0 % )
# {'WaterBottle', 'RazerBlades'} => { Desk } ( 30.0 %, 75.0 % )
# {'WaterBottle', 'Desk'} => { RazerBlades } ( 30.0 %, 75.0 % )
# {'Desk', 'RazerBlades'} => { WaterBottle } ( 30.0 %, 85.71428571428571 % )
# {'WaterBottle', 'RazerBlades'} => { MangoJuice } ( 30.0 %, 75.0 % )
# {'MangoJuice', 'WaterBottle'} => { RazerBlades } ( 30.0 %, 66.66666666666666 % )
# {'MangoJuice', 'RazerBlades'} => { WaterBottle } ( 30.0 %, 75.0 % )
# {'MangoJuice', 'Water'} => { Chips } ( 30.0 %, 85.71428571428571 % )
# {'Chips', 'Water'} => { MangoJuice } ( 30.0 %, 75.0 % )
# {'Chips', 'MangoJuice'} => { Water } ( 30.0 %, 75.0 % )
# {'WaterBottle', 'Tomato'} => { RazerBlades } ( 30.0 %, 66.66666666666666 % )
# {'WaterBottle', 'RazerBlades'} => { Tomato } ( 30.0 %, 75.0 % )
# {'RazerBlades', 'Tomato'} => { WaterBottle } ( 30.0 %, 66.66666666666666 % )
# {'MangoJuice', 'Lamp'} => { Chips } ( 30.0 %, 75.0 % )
# {'Chips', 'MangoJuice'} => { Lamp } ( 30.0 %, 75.0 % )
# {'Chips', 'Lamp'} => { MangoJuice } ( 30.0 %, 75.0 % )
# {'Moisturizer', 'WaterBottle'} => { Desk } ( 35.0 %, 77.77777777777779 % )
# {'WaterBottle', 'Desk'} => { Moisturizer } ( 35.0 %, 87.5 % )
# {'Moisturizer', 'Desk'} => { WaterBottle } ( 35.0 %, 77.77777777777779 % )
# {'Shoes', 'RazerBlades'} => { Notebook } ( 35.0 %, 100.0 % )
# {'Shoes', 'Notebook'} => { RazerBlades } ( 35.0 %, 87.5 % )
# {'RazerBlades', 'Notebook'} => { Shoes } ( 35.0 %, 77.77777777777779 % )
# {'Notebook', 'Mouse'} => { Chips } ( 30.0 %, 85.71428571428571 % )
# {'Chips', 'Notebook'} => { Mouse } ( 30.0 %, 66.66666666666666 % )
# {'Chips', 'Mouse'} => { Notebook } ( 30.0 %, 75.0 % )
# {'Moisturizer', 'RazerBlades'} => { Chips } ( 30.0 %, 66.66666666666666 % )
# {'Chips', 'RazerBlades'} => { Moisturizer } ( 30.0 %, 75.0 % )
# {'Moisturizer', 'Chips'} => { RazerBlades } ( 30.0 %, 75.0 % )
# {'Eggs', 'Notebook'} => { Bed } ( 30.0 %, 75.0 % )
# {'Bed', 'Notebook'} => { Eggs } ( 30.0 %, 66.66666666666666 % )
# {'Bed', 'Eggs'} => { Notebook } ( 30.0 %, 100.0 % )
# {'WaterBottle', 'Tomato'} => { MangoJuice } ( 35.0 %, 77.77777777777779 % )
# {'MangoJuice', 'WaterBottle'} => { Tomato } ( 35.0 %, 77.77777777777779 % )
# {'MangoJuice', 'Tomato'} => { WaterBottle } ( 35.0 %, 77.77777777777779 % )
# {'WaterBottle', 'Tomato'} => { Chips } ( 30.0 %, 66.66666666666666 % )
# {'Chips', 'WaterBottle'} => { Tomato } ( 30.0 %, 66.66666666666666 % )
# {'Chips', 'Tomato'} => { WaterBottle } ( 30.0 %, 66.66666666666666 % )
# {'Notebook', 'Mouse'} => { Eggs } ( 30.0 %, 85.71428571428571 % )
# {'Eggs', 'Notebook'} => { Mouse } ( 30.0 %, 75.0 % )
# {'Eggs', 'Mouse'} => { Notebook } ( 30.0 %, 75.0 % )
# {'Notebook', 'WetWipes'} => { Eggs } ( 30.0 %, 85.71428571428571 % )
# {'Eggs', 'WetWipes'} => { Notebook } ( 30.0 %, 100.0 % )
# {'Eggs', 'Notebook'} => { WetWipes } ( 30.0 %, 75.0 % )
# {'Moisturizer', 'Tomato'} => { Chips } ( 30.0 %, 66.66666666666666 % )
# {'Chips', 'Tomato'} => { Moisturizer } ( 30.0 %, 66.66666666666666 % )
# {'Moisturizer', 'Chips'} => { Tomato } ( 30.0 %, 75.0 % )
# {'ChickenBreast', 'Notebook'} => { Bed } ( 30.0 %, 100.0 % )
# {'Bed', 'Notebook'} => { ChickenBreast } ( 30.0 %, 66.66666666666666 % )
# {'Bed', 'ChickenBreast'} => { Notebook } ( 30.0 %, 85.71428571428571 % )
# {'WaterBottle', 'Sunscreen'} => { Notebook } ( 30.0 %, 75.0 % )
# {'WaterBottle', 'Notebook'} => { Sunscreen } ( 30.0 %, 66.66666666666666 % )
# {'Sunscreen', 'Notebook'} => { WaterBottle } ( 30.0 %, 100.0 % )
# {'WaterBottle', 'Tomato'} => { ShavingCream } ( 30.0 %, 66.66666666666666 % )
# {'WaterBottle', 'ShavingCream'} => { Tomato } ( 30.0 %, 85.71428571428571 % )
# {'Tomato', 'ShavingCream'} => { WaterBottle } ( 30.0 %, 60.0 % )
# {'Moisturizer', 'Chocolates'} => { Chips } ( 30.0 %, 85.71428571428571 % )
# {'Moisturizer', 'Chips'} => { Chocolates } ( 30.0 %, 75.0 % )
# {'Chips', 'Chocolates'} => { Moisturizer } ( 30.0 %, 85.71428571428571 % )
# {'WaterBottle', 'Eggs'} => { Chips } ( 30.0 %, 75.0 % )
# {'Chips', 'WaterBottle'} => { Eggs } ( 30.0 %, 66.66666666666666 % )
# {'Chips', 'Eggs'} => { WaterBottle } ( 30.0 %, 85.71428571428571 % )
# {'Shoes', 'Notebook'} => { ChickenBreast } ( 30.0 %, 75.0 % )
# {'ChickenBreast', 'Shoes'} => { Notebook } ( 30.0 %, 75.0 % )
# {'ChickenBreast', 'Notebook'} => { Shoes } ( 30.0 %, 100.0 % )
# {'RazerBlades', 'Notebook'} => { Eggs } ( 30.0 %, 66.66666666666666 % )
# {'Eggs', 'RazerBlades'} => { Notebook } ( 30.0 %, 85.71428571428571 % )
# {'Eggs', 'Notebook'} => { RazerBlades } ( 30.0 %, 75.0 % )
# {'WaterBottle', 'Notebook'} => { Eggs } ( 35.0 %, 77.77777777777779 % )
# {'WaterBottle', 'Eggs'} => { Notebook } ( 35.0 %, 87.5 % )
# {'Eggs', 'Notebook'} => { WaterBottle } ( 35.0 %, 87.5 % )
# {'Notebook', 'Tomato'} => { Chips } ( 30.0 %, 75.0 % )
# {'Chips', 'Tomato'} => { Notebook } ( 30.0 %, 66.66666666666666 % )
# {'Chips', 'Notebook'} => { Tomato } ( 30.0 %, 66.66666666666666 % )
# {'Notebook', 'ShavingCream'} => { Bed } ( 30.0 %, 85.71428571428571 % )
# {'Bed', 'ShavingCream'} => { Notebook } ( 30.0 %, 75.0 % )
# {'Bed', 'Notebook'} => { ShavingCream } ( 30.0 %, 66.66666666666666 % )
# {'Moisturizer', 'WetWipes'} => { Desk } ( 30.0 %, 85.71428571428571 % )
# {'Desk', 'WetWipes'} => { Moisturizer } ( 30.0 %, 100.0 % )
# {'Moisturizer', 'Desk'} => { WetWipes } ( 30.0 %, 66.66666666666666 % )
# {'Shoes', 'WaterBottle'} => { Notebook } ( 30.0 %, 85.71428571428571 % )
# {'WaterBottle', 'Notebook'} => { Shoes } ( 30.0 %, 66.66666666666666 % )
# {'Shoes', 'Notebook'} => { WaterBottle } ( 30.0 %, 75.0 % )
# {'Umbrella', 'Mouse'} => { Chips } ( 30.0 %, 75.0 % )
# {'Chips', 'Umbrella'} => { Mouse } ( 30.0 %, 85.71428571428571 % )
# {'Chips', 'Mouse'} => { Umbrella } ( 30.0 %, 75.0 % )
# {'Notebook', 'Tomato'} => { Bed } ( 30.0 %, 75.0 % )
# {'Bed', 'Tomato'} => { Notebook } ( 30.0 %, 85.71428571428571 % )
# {'Bed', 'Notebook'} => { Tomato } ( 30.0 %, 66.66666666666666 % )
# {'Tomato', 'ShavingCream'} => { Bed } ( 30.0 %, 60.0 % )
# {'Bed', 'Tomato'} => { ShavingCream } ( 30.0 %, 85.71428571428571 % )
# {'Bed', 'ShavingCream'} => { Tomato } ( 30.0 %, 75.0 % )
# {'Moisturizer', 'Notebook'} => { Eggs } ( 35.0 %, 87.5 % )
# {'Eggs', 'Notebook'} => { Moisturizer } ( 35.0 %, 87.5 % )
# {'Moisturizer', 'Eggs'} => { Notebook } ( 35.0 %, 87.5 % )
# {'Water', 'LightBulb'} => { Chips } ( 30.0 %, 85.71428571428571 % )
# {'Chips', 'Water'} => { LightBulb } ( 30.0 %, 75.0 % )
# {'Chips', 'LightBulb'} => { Water } ( 30.0 %, 75.0 % )
# {'RazerBlades', 'Notebook'} => { Chips } ( 30.0 %, 66.66666666666666 % )
# {'Chips', 'RazerBlades'} => { Notebook } ( 30.0 %, 75.0 % )
# {'Chips', 'Notebook'} => { RazerBlades } ( 30.0 %, 66.66666666666666 % )
# {'WaterBottle', 'Tomato'} => { Sunscreen } ( 30.0 %, 66.66666666666666 % )
# {'WaterBottle', 'Sunscreen'} => { Tomato } ( 30.0 %, 75.0 % )
# {'Sunscreen', 'Tomato'} => { WaterBottle } ( 30.0 %, 85.71428571428571 % )
# {'Lamp', 'LightBulb'} => { Chips } ( 30.0 %, 75.0 % )
# {'Chips', 'LightBulb'} => { Lamp } ( 30.0 %, 75.0 % )
# {'Chips', 'Lamp'} => { LightBulb } ( 30.0 %, 75.0 % )
# {'Moisturizer', 'Mouse'} => { Eggs } ( 30.0 %, 100.0 % )
# {'Eggs', 'Mouse'} => { Moisturizer } ( 30.0 %, 75.0 % )
# {'Moisturizer', 'Eggs'} => { Mouse } ( 30.0 %, 75.0 % )
# {'Shoes', 'Tomato'} => { ShavingCream } ( 30.0 %, 75.0 % )
# {'Tomato', 'ShavingCream'} => { Shoes } ( 30.0 %, 60.0 % )
# {'Shoes', 'ShavingCream'} => { Tomato } ( 30.0 %, 85.71428571428571 % )
# {'RazerBlades', 'Mouse'} => { Chips } ( 30.0 %, 85.71428571428571 % )
# {'Chips', 'RazerBlades'} => { Mouse } ( 30.0 %, 75.0 % )
# {'Chips', 'Mouse'} => { RazerBlades } ( 30.0 %, 75.0 % )
# {'Eggs', 'Mouse'} => { Chocolates } ( 30.0 %, 75.0 % )
# {'Chocolates', 'Mouse'} => { Eggs } ( 30.0 %, 85.71428571428571 % )
# {'Eggs', 'Chocolates'} => { Mouse } ( 30.0 %, 100.0 % )
# {'Moisturizer', 'WaterBottle'} => { Eggs } ( 35.0 %, 77.77777777777779 % )
# {'WaterBottle', 'Eggs'} => { Moisturizer } ( 35.0 %, 87.5 % )
# {'Moisturizer', 'Eggs'} => { WaterBottle } ( 35.0 %, 87.5 % )
# {'Eggs', 'Mouse'} => { Chips } ( 30.0 %, 75.0 % )
# {'Chips', 'Mouse'} => { Eggs } ( 30.0 %, 75.0 % )
# {'Chips', 'Eggs'} => { Mouse } ( 30.0 %, 85.71428571428571 % )
# {'Moisturizer', 'MangoJuice'} => { Desk } ( 30.0 %, 75.0 % )
# {'Moisturizer', 'Desk'} => { MangoJuice } ( 30.0 %, 66.66666666666666 % )
# {'MangoJuice', 'Desk'} => { Moisturizer } ( 30.0 %, 100.0 % )
# {'Shoes', 'Tomato'} => { Fan } ( 35.0 %, 87.5 % )
# {'Fan', 'Tomato'} => { Shoes } ( 35.0 %, 77.77777777777779 % )
# {'Shoes', 'Fan'} => { Tomato } ( 35.0 %, 87.5 % )
# {'RazerBlades', 'Onion'} => { Notebook } ( 30.0 %, 85.71428571428571 % )
# {'RazerBlades', 'Notebook'} => { Onion } ( 30.0 %, 66.66666666666666 % )
# {'Onion', 'Notebook'} => { RazerBlades } ( 30.0 %, 100.0 % )
# {'Shoes', 'Notebook'} => { Eggs } ( 30.0 %, 75.0 % )
# {'Shoes', 'Eggs'} => { Notebook } ( 30.0 %, 100.0 % )
# {'Eggs', 'Notebook'} => { Shoes } ( 30.0 %, 75.0 % )
# {'Umbrella', 'Mouse'} => { Eggs } ( 35.0 %, 87.5 % )
# {'Eggs', 'Umbrella'} => { Mouse } ( 35.0 %, 100.0 % )
# {'Eggs', 'Mouse'} => { Umbrella } ( 35.0 %, 87.5 % )
# {'Moisturizer', 'MangoJuice'} => { Chips } ( 30.0 %, 75.0 % )
# {'Moisturizer', 'Chips'} => { MangoJuice } ( 30.0 %, 75.0 % )
# {'Chips', 'MangoJuice'} => { Moisturizer } ( 30.0 %, 75.0 % )
# {'Moisturizer', 'RazerBlades'} => { Eggs } ( 35.0 %, 77.77777777777779 % )
# {'Eggs', 'RazerBlades'} => { Moisturizer } ( 35.0 %, 100.0 % )
# {'Moisturizer', 'Eggs'} => { RazerBlades } ( 35.0 %, 87.5 % )
# {'WaterBottle', 'Sunscreen'} => { Lamp } ( 30.0 %, 75.0 % )
# {'WaterBottle', 'Lamp'} => { Sunscreen } ( 30.0 %, 85.71428571428571 % )
# {'Lamp', 'Sunscreen'} => { WaterBottle } ( 30.0 %, 100.0 % )
# {'Pen', 'ShavingCream'} => { Bed } ( 30.0 %, 85.71428571428571 % )
# {'Bed', 'ShavingCream'} => { Pen } ( 30.0 %, 75.0 % )
# {'Bed', 'Pen'} => { ShavingCream } ( 30.0 %, 100.0 % )
# {'RazerBlades', 'Tomato'} => { Chips } ( 30.0 %, 66.66666666666666 % )
# {'Chips', 'Tomato'} => { RazerBlades } ( 30.0 %, 66.66666666666666 % )
# {'Chips', 'RazerBlades'} => { Tomato } ( 30.0 %, 75.0 % )
# {'Notebook', 'LightBulb'} => { Chips } ( 30.0 %, 85.71428571428571 % )
# {'Chips', 'Notebook'} => { LightBulb } ( 30.0 %, 66.66666666666666 % )
# {'Chips', 'LightBulb'} => { Notebook } ( 30.0 %, 75.0 % )
# {'WaterBottle', 'RazerBlades'} => { Moisturizer } ( 35.0 %, 87.5 % )
# {'Moisturizer', 'WaterBottle'} => { RazerBlades } ( 35.0 %, 77.77777777777779 % )
# {'Moisturizer', 'RazerBlades'} => { WaterBottle } ( 35.0 %, 77.77777777777779 % )
# {'Notebook', 'LightBulb'} => { Lamp } ( 30.0 %, 85.71428571428571 % )
# {'Lamp', 'Notebook'} => { LightBulb } ( 30.0 %, 85.71428571428571 % )
# {'Lamp', 'LightBulb'} => { Notebook } ( 30.0 %, 75.0 % )
# {'Moisturizer', 'Shorts'} => { Desk } ( 30.0 %, 100.0 % )
# {'Desk', 'Shorts'} => { Moisturizer } ( 30.0 %, 85.71428571428571 % )
# {'Moisturizer', 'Desk'} => { Shorts } ( 30.0 %, 66.66666666666666 % )
# {'Chocolates', 'Mouse'} => { Chips } ( 30.0 %, 85.71428571428571 % )
# {'Chips', 'Mouse'} => { Chocolates } ( 30.0 %, 75.0 % )
# {'Chips', 'Chocolates'} => { Mouse } ( 30.0 %, 85.71428571428571 % )
# {'Shoes', 'Notebook'} => { Bed } ( 30.0 %, 75.0 % )
# {'Bed', 'Shoes'} => { Notebook } ( 30.0 %, 100.0 % )
# {'Bed', 'Notebook'} => { Shoes } ( 30.0 %, 66.66666666666666 % )
# {'Notebook', 'WetWipes'} => { Bed } ( 30.0 %, 85.71428571428571 % )
# {'Bed', 'WetWipes'} => { Notebook } ( 30.0 %, 100.0 % )
# {'Bed', 'Notebook'} => { WetWipes } ( 30.0 %, 66.66666666666666 % )
# {'Moisturizer', 'Eggs'} => { Desk } ( 30.0 %, 75.0 % )
# {'Moisturizer', 'Desk'} => { Eggs } ( 30.0 %, 66.66666666666666 % )
# {'Desk', 'Eggs'} => { Moisturizer } ( 30.0 %, 85.71428571428571 % )
# {'Moisturizer', 'WaterBottle'} => { Chocolates } ( 30.0 %, 66.66666666666666 % )
# {'WaterBottle', 'Chocolates'} => { Moisturizer } ( 30.0 %, 100.0 % )
# {'Moisturizer', 'Chocolates'} => { WaterBottle } ( 30.0 %, 85.71428571428571 % )
# {'WaterBottle', 'Tomato'} => { Pen } ( 30.0 %, 66.66666666666666 % )
# {'WaterBottle', 'Pen'} => { Tomato } ( 30.0 %, 75.0 % )
# {'Pen', 'Tomato'} => { WaterBottle } ( 30.0 %, 75.0 % )
# {'Moisturizer', 'Notebook'} => { Desk } ( 30.0 %, 75.0 % )
# {'Desk', 'Notebook'} => { Moisturizer } ( 30.0 %, 100.0 % )
# {'Moisturizer', 'Desk'} => { Notebook } ( 30.0 %, 66.66666666666666 % )
# {'WaterBottle', 'Sunscreen', 'Notebook'} => { MangoJuice } ( 30.0 %, 100.0 % )
# {'MangoJuice', 'WaterBottle', 'Sunscreen'} => { Notebook } ( 30.0 %, 85.71428571428571 % )
# {'MangoJuice', 'WaterBottle', 'Notebook'} => { Sunscreen } ( 30.0 %, 100.0 % )
# {'MangoJuice', 'Sunscreen', 'Notebook'} => { WaterBottle } ( 30.0 %, 100.0 % )
# {'Moisturizer', 'WaterBottle', 'Tomato'} => { MangoJuice } ( 30.0 %, 100.0 % )
# {'MangoJuice', 'WaterBottle', 'Tomato'} => { Moisturizer } ( 30.0 %, 85.71428571428571 % )
# {'Moisturizer', 'MangoJuice', 'WaterBottle'} => { Tomato } ( 30.0 %, 85.71428571428571 % )
# {'Moisturizer', 'MangoJuice', 'Tomato'} => { WaterBottle } ( 30.0 %, 85.71428571428571 % )
# {'Moisturizer', 'WaterBottle', 'Notebook'} => { Eggs } ( 30.0 %, 100.0 % )
# {'WaterBottle', 'Eggs', 'Notebook'} => { Moisturizer } ( 30.0 %, 85.71428571428571 % )
# {'Moisturizer', 'WaterBottle', 'Eggs'} => { Notebook } ( 30.0 %, 85.71428571428571 % )
# {'Moisturizer', 'Eggs', 'Notebook'} => { WaterBottle } ( 30.0 %, 85.71428571428571 % )
# {'Moisturizer', 'RazerBlades', 'Notebook'} => { Bed } ( 30.0 %, 85.71428571428571 % )
# {'Bed', 'RazerBlades', 'Notebook'} => { Moisturizer } ( 30.0 %, 85.71428571428571 % )
# {'Moisturizer', 'Bed', 'RazerBlades'} => { Notebook } ( 30.0 %, 100.0 % )
# {'Moisturizer', 'Bed', 'Notebook'} => { RazerBlades } ( 30.0 %, 100.0 % )
# {'WaterBottle', 'RazerBlades', 'Tomato'} => { MangoJuice } ( 30.0 %, 100.0 % )
# {'MangoJuice', 'WaterBottle', 'Tomato'} => { RazerBlades } ( 30.0 %, 85.71428571428571 % )
# {'MangoJuice', 'RazerBlades', 'WaterBottle'} => { Tomato } ( 30.0 %, 100.0 % )
# {'MangoJuice', 'RazerBlades', 'Tomato'} => { WaterBottle } ( 30.0 %, 85.71428571428571 % )
# {'ChickenBreast', 'Shoes', 'Notebook'} => { Bed } ( 30.0 %, 100.0 % )
# {'Bed', 'Shoes', 'Notebook'} => { ChickenBreast } ( 30.0 %, 100.0 % )
# {'Bed', 'ChickenBreast', 'Shoes'} => { Notebook } ( 30.0 %, 100.0 % )
# {'Bed', 'ChickenBreast', 'Notebook'} => { Shoes } ( 30.0 %, 100.0 % )
# {'Moisturizer', 'WaterBottle', 'Eggs'} => { Desk } ( 30.0 %, 85.71428571428571 % )
# {'Moisturizer', 'WaterBottle', 'Desk'} => { Eggs } ( 30.0 %, 85.71428571428571 % )
# {'WaterBottle', 'Desk', 'Eggs'} => { Moisturizer } ( 30.0 %, 100.0 % )
# {'Moisturizer', 'Desk', 'Eggs'} => { WaterBottle } ( 30.0 %, 100.0 % )
# {'Moisturizer', 'RazerBlades', 'Notebook'} => { Eggs } ( 30.0 %, 85.71428571428571 % )
# {'Eggs', 'RazerBlades', 'Notebook'} => { Moisturizer } ( 30.0 %, 100.0 % )
# {'Moisturizer', 'Eggs', 'RazerBlades'} => { Notebook } ( 30.0 %, 85.71428571428571 % )
# {'Moisturizer', 'Eggs', 'Notebook'} => { RazerBlades } ( 30.0 %, 85.71428571428571 % )
# {'Moisturizer', 'RazerBlades', 'Tomato'} => { MangoJuice } ( 30.0 %, 85.71428571428571 % )
# {'MangoJuice', 'RazerBlades', 'Tomato'} => { Moisturizer } ( 30.0 %, 85.71428571428571 % )
# {'Moisturizer', 'MangoJuice', 'Tomato'} => { RazerBlades } ( 30.0 %, 85.71428571428571 % )
# {'Moisturizer', 'MangoJuice', 'RazerBlades'} => { Tomato } ( 30.0 %, 100.0 % )
# {'Moisturizer', 'WaterBottle', 'RazerBlades'} => { Desk } ( 30.0 %, 85.71428571428571 % )
# {'WaterBottle', 'Desk', 'RazerBlades'} => { Moisturizer } ( 30.0 %, 100.0 % )
# {'Moisturizer', 'WaterBottle', 'Desk'} => { RazerBlades } ( 30.0 %, 85.71428571428571 % )
# {'Moisturizer', 'Desk', 'RazerBlades'} => { WaterBottle } ( 30.0 %, 85.71428571428571 % )
# {'Moisturizer', 'WaterBottle', 'RazerBlades'} => { Eggs } ( 30.0 %, 85.71428571428571 % )
# {'WaterBottle', 'Eggs', 'RazerBlades'} => { Moisturizer } ( 30.0 %, 100.0 % )
# {'Moisturizer', 'WaterBottle', 'Eggs'} => { RazerBlades } ( 30.0 %, 85.71428571428571 % )
# {'Moisturizer', 'Eggs', 'RazerBlades'} => { WaterBottle } ( 30.0 %, 85.71428571428571 % )
# Time to execute Apriori Algorithim --- 0.6579959392547607 seconds
